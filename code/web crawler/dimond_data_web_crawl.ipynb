', '2225417471', '7125217', '可訂購', '1373609142', '19934', '可訂購', '6391565179', '20599', '可訂購', '7401764483', '20599', '可訂購', '6425621327', '21263', '可訂購', '7446331047', '21263', '可訂購', '7406705953', '21263', '可訂購', '1425109055', '21263', '可訂購', '6442263732', '21927', '可訂購', '7438735394', '21927', '可訂購', '6445071982', '21927', '可訂購', '2436994741', '21927', '可訂購', '1409118305', '21927', '可訂購', '6441344061', '21927', '可訂購', '1388051525', '36532', '可訂購', '6431227633', '36532', '可訂購', '1433814941', '36532', '可訂購', '6372931749', '37445', '可訂購', '2427983426', '59830', '可訂購', '7416043940', '59830', '可訂購', '2436182231', '59830', '可訂購', '5426522510', '59830', '可訂購', '7421328899', '59830', '可訂購', '6422940827', '59830', '可訂購', '6422949421', '59830', '可訂購', '3435060038', '59830', '可訂購', '2407795100', '59830', '可訂購', '3425802938', '59830', '可訂購', '1433137616', '59830', '可訂購', '6432138341', '59830', '可訂購', '6435138568', '59830', '可訂購', '6432137276', '59830', '可訂購', '2434158547', '59830', '可訂購', '6432177949', '59830', '可訂購', '5416718462', '59830', '可訂購', '6421594718', '59830', '可訂購', '6227370005', '59830', '可訂購', '7436414639', '59830', '可訂購', '6431912322', '59830', '可訂購', '7431333301', '59830', '可訂購', '6432749644', '59830', '可訂購', '6432762488 ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

gcarat = []
gcolor = []
gclarity = []
gdmh = []
gtmh = []
# gcmh = []
gpmh = []
gsmh = []
gfmh = []
ghmh = []
ok_gstate = []
no_gstage1 = []
no_gstage2 = []

for i in range(1,35):
    url = 'https://dy-jewelry.com/gia.php?&page=' + str(i)
    response = requests.get(url=url)
    soup = BeautifulSoup(response.text, 'html.parser')

    
    gcarat1 = soup.find_all('td', class_='gia-carat')
    for gia_carat in gcarat1:
        gcarat.append(gia_carat.text)

        
    gcolor1 = soup.find_all('td', class_='gia-color')
    for gia_color in gcolor1:
        gcolor.append(gia_color.text)

    
    gclarity1 = soup.find_all('td', class_='gia-clarity')
    for gia_clarity in gclarity1:
        gclarity.append(gia_clarity.text)

    
    gdmh1 = soup.find_all('td', class_='gia-depth m-hide')
    for gia_depth_m_hide in gdmh1:
        gdmh.append(gia_depth_m_hide.text)

    
    gtmh1 = soup.find_all('td', class_='gia-table m-hide')
    for gia_table_m_hide in gtmh1:
        gtmh.append(gia_table_m_hide.text)

    
    # gcmh1 = soup.find_all('td', 'gia-polish m-hide')
    # for gia_cut_m_hide in gcmh1:
    #     gcmh.append(gia_cut_m_hide.find('a').text)


    
    gpmh1 = soup.find_all('td', 'gia-polish m-hide')
    for gia_polish_m_hide in gpmh1:
        gpmh.append(gia_polish_m_hide.find('a').text)

        
    gsmh1 = soup.find_all('td', 'gia-polish m-hide')
    for gia_sym_m_hide in gsmh1:
        gsmh.append(gia_sym_m_hide.find('a').text)

    
    gfmh1 = soup.find_all('td', class_='gia-flourescence m-hide')
    for gia_flourescence_m_hide in gfmh1:
        gfmh.append(gia_flourescence_m_hide.text)

    
    ghmh1 = soup.find_all('td', class_='gia-heart m-hide')
    for gia_heart_m_hide in ghmh1:
        ghmh.append(gia_heart_m_hide.text)

    
    gstate1 = soup.find_all('td', class_='gia-state m-hide')
    for gia_state_m_hid in gstate1:
        ok_gstate.append(gia_state_m_hid.text)
        
    ghmh = map(lambda s: s.strip(), ghmh)
    ghmh = list(ghmh)
    
    gstate4 = str(ok_gstate).replace(u'\\t', '')
    gstate4 = str(gstate4).replace(u'\\n', '')
    gstate4 = str(gstate4).replace(u'\\xa0', ' ')
    # print(type(gstate4))
    gstate4 = gstate4.replace(u'    ', ' ')

    # print(type(gstate4))
    gstate4 = gstate4.replace(u'   ', ' ')
    gstate4 = gstate4.replace(u'[', '')
    gstate4 = gstate4.replace(u']', '')
    gstate4 = gstate4.replace(u"'", '')
    gstate4 = gstate4.replace(u",", '')
    gstate4 = gstate4.replace(u"GIA證書連結：", '')
    gstate4 = gstate4.replace(u"含稅價格：NT", '')
    # print(gstate4)
    gstate4 = gstate4.split()
# Out:
# 1done
# 2done
# 3done
# 4done
# 5done
# 6done
# 7done
# 8done
# 9done
# 10done
# 11done
# 12done
# 13done
# 14done
# 15done
# 16done
# 17done
# 18done
# 19done
# 20done
# 21done
# 22done
# 23done
# 24done
# 25done
# 26done
# 27done
# 28done
# 29done
# 30done
# 31done
# 32done
# 33done
# 34done

# %%
print(f'gcarat:{len(gcarat)}\ngcolor:{len(gcolor)}\ngclarity:{len(gclarity)}\ngdmh:{len(gdmh)}\ngtmh:{len(gtmh)}\ngpmh:{len(gpmh)}\ngsmh:{len(gsmh)}\ngfmh:{len(gfmh)}\nghmh:{len(ghmh)}\n')
# Out:
# gcarat:666
# gcolor:666
# gclarity:666
# gdmh:666
# gtmh:666
# gpmh:666
# gsmh:666
# gfmh:666
# ghmh:666

# %%
for i in range(1,3):
    url = 'https://dy-jewelry.com/gia_heart.php?&page=' + str(i)
    response = requests.get(url=url)
    soup = BeautifulSoup(response.text, 'html.parser')

    
    gcarat1 = soup.find_all('td', class_='gia-carat')
    for gia_carat in gcarat1:
        gcarat.append(gia_carat.text)

        
    gcolor1 = soup.find_all('td', class_='gia-color')
    for gia_color in gcolor1:
        gcolor.append(gia_color.text)

    
    gclarity1 = soup.find_all('td', class_='gia-clarity')
    for gia_clarity in gclarity1:
        gclarity.append(gia_clarity.text)

    
    gdmh1 = soup.find_all('td', class_='gia-depth m-hide')
    for gia_depth_m_hide in gdmh1:
        gdmh.append(gia_depth_m_hide.text)

    
    gtmh1 = soup.find_all('td', class_='gia-table m-hide')
    for gia_table_m_hide in gtmh1:
        gtmh.append(gia_table_m_hide.text)

    
    # gcmh1 = soup.find_all('td', 'gia-polish m-hide')
    # for gia_cut_m_hide in gcmh1:
    #     gcmh.append(gia_cut_m_hide.find('a').text)


    
    gpmh1 = soup.find_all('td', 'gia-polish m-hide')
    for gia_polish_m_hide in gpmh1:
        gpmh.append(gia_polish_m_hide.find('a').text)

        
    gsmh1 = soup.find_all('td', 'gia-polish m-hide')
    for gia_sym_m_hide in gsmh1:
        gsmh.append(gia_sym_m_hide.find('a').text)

    
    gfmh1 = soup.find_all('td', class_='gia-flourescence m-hide')
    for gia_flourescence_m_hide in gfmh1:
        gfmh.append(gia_flourescence_m_hide.text)

    
    gstate1 = soup.find_all('td', class_='gia-state m-hide')
    for gia_state_m_hid in gstate1:
        no_gstage1.append(gia_state_m_hid.text)
        
    gstate5 = str(no_gstage1).replace(u'\\t', '')
    gstate5 = str(gstate5).replace(u'\\n', ' ')
    gstate5 = gstate5.replace(u'[', '')
    gstate5 = gstate5.replace(u']', '')
    gstate5 = gstate5.replace(u"'", '')
    gstate5 = gstate5.replace(u",", '')
    gstate5 = gstate5.replace(u"GIA證書連結：", '')
    gstate5 = gstate5.replace(u"含稅價格：NT ", '')
    gstate5 = gstate5.split()
    gstate5

    print(f'{i}done')
# Out:
# 1done
# 2done

# %%
print(f'gcarat:{len(gcarat)}\ngcolor:{len(gcolor)}\ngclarity:{len(gclarity)}\ngdmh:{len(gdmh)}\ngtmh:{len(gtmh)}\ngpmh:{len(gpmh)}\ngsmh:{len(gsmh)}\ngfmh:{len(gfmh)}\nghmh:{len(ghmh)}\nno_gstage1:{len(no_gstage1)}')
# Out:
# gcarat:688
# gcolor:688
# gclarity:688
# gdmh:688
# gtmh:688
# gpmh:688
# gsmh:688
# gfmh:688
# ghmh:666
# no_gstage1:22

# %%
for i in range(1,3):
    url = 'https://dy-jewelry.com/gia_color.php?&page=' + str(i)
    response = requests.get(url=url)
    soup = BeautifulSoup(response.text, 'html.parser')

    
    gcarat1 = soup.find_all('td', class_='gia-carat')
    for gia_carat in gcarat1:
        gcarat.append(gia_carat.text)

        
    gcolor1 = soup.find_all('td', class_='gia-color')
    for gia_color in gcolor1:
        gcolor.append(gia_color.text)

    
    gclarity1 = soup.find_all('td', class_='gia-clarity')
    for gia_clarity in gclarity1:
        gclarity.append(gia_clarity.text)

    
    gdmh1 = soup.find_all('td', class_='gia-depth m-hide')
    for gia_depth_m_hide in gdmh1:
        gdmh.append(gia_depth_m_hide.text)

    
    gtmh1 = soup.find_all('td', class_='gia-table m-hide')
    for gia_table_m_hide in gtmh1:
        gtmh.append(gia_table_m_hide.text)

    
    # gcmh1 = soup.find_all('td', 'gia-polish m-hide')
    # for gia_cut_m_hide in gcmh1:
    #     gcmh.append(gia_cut_m_hide.find('a').text)


    
    gpmh1 = soup.find_all('td', 'gia-polish m-hide')
    for gia_polish_m_hide in gpmh1:
        gpmh.append(gia_polish_m_hide.find('a').text)

        
    gsmh1 = soup.find_all('td', 'gia-polish m-hide')
    for gia_sym_m_hide in gsmh1:
        gsmh.append(gia_sym_m_hide.find('a').text)

    
    gfmh1 = soup.find_all('td', class_='gia-flourescence m-hide')
    for gia_flourescence_m_hide in gfmh1:
        gfmh.append(gia_flourescence_m_hide.text)

    
    # ghmh1 = soup.find_all('td', class_='gia-heart m-hide')
    # for gia_heart_m_hide in ghmh1:
    #     ghmh.append(gia_heart_m_hide.text)
    #     ghmh = map(lambda s: s.strip(), ghmh)
    #     ghmh = list(ghmh)

    
    gstate1 = soup.find_all('td', class_='gia-state m-hide')
    for gia_state_m_hid in gstate1:
        no_gstage2.append(gia_state_m_hid.text)
        
    
    
    gstate6 = str(no_gstage2).replace(u'\\t', '')
    gstate6 = str(gstate6).replace(u'\\n', ' ')
    gstate6 = str(gstate6).replace(u'\\xa0', ' ')
    # print(type(gstate4))
    # gstate5 = gstate5.replace(u'    ', ' ')

    # # print(type(gstate4))
    # gstate5 = gstate5.replace(u'   ', ' ')
    gstate6 = gstate6.replace(u'[', '')
    gstate6 = gstate6.replace(u']', '')
    gstate6 = gstate6.replace(u"'", '')
    gstate6 = gstate6.replace(u",", '')
    gstate6 = gstate6.replace(u"GIA證書連結：", '')
    gstate6 = gstate6.replace(u"含稅價格：NT ", '')
    # # print(gstate4)
    gstate6 = gstate6.split()
    print(f'{i}done')
# Out:
# 1done
# 2done

# %%
print(f'gcarat:{len(gcarat)}\ngcolor:{len(gcolor)}\ngclarity:{len(gclarity)}\ngdmh:{len(gdmh)}\ngtmh:{len(gtmh)}\ngpmh:{len(gpmh)}\ngsmh:{len(gsmh)}\ngfmh:{len(gfmh)}\nghmh:{len(ghmh)}\nno_gstage1:{len(no_gstage1)}\nno_gstage2:{len(no_gstage2)}')
# Out:
# gcarat:725
# gcolor:725
# gclarity:725
# gdmh:725
# gtmh:725
# gpmh:725
# gsmh:725
# gfmh:725
# ghmh:666
# no_gstage1:22
# no_gstage2:37

# %%
total_gstage = gstate4 + gstate5 + gstate6
len(total_gstage)
# Out:
# 2175

# %%
n = 3
c = [total_gstage[i:i+n] for i in range(0, len(total_gstage), n)]

# %%
dff = pd.DataFrame(c)
dff.columns = ['State', 'GIA_NO', 'Price']

# %%
dff
# Out:
#     State      GIA_NO   Price
# 0     可訂購  6224158906   53147
# 1     可訂購  2225073060  108677
# 2     可訂購  5212837414  267836
# 3     可訂購  6224197742  694088
# 4     可訂購  6402769643  745502
# ..    ...         ...     ...
# 720   可訂購  1132222109  593334
# 721   可訂購  2316566935  171171
# 722   可訂購  6311582640  177177
# 723   可訂購  2101851815  190691
# 724   可訂購  6215705830  207165
#
# [725 rows x 3 columns]

# %%
d = {'gcarat':gcarat, 'gcolor':gcolor, 'gclarity':gclarity, 'gdmh':gdmh, 'gtmh':gtmh, 'gpmh':gpmh, 'gsmh':gsmh, 'gfmh':gfmh}
df = pd.DataFrame(d)

d2 = pd.merge(dff, df, left_index = True, right_index=True)

d2.to_csv('dimond_test.csv',index=None)

# %%
ghmhd = pd.DataFrame(ghmh, columns=['ghmh'])
ghmhd
# Out:
#     ghmh
# 0    H&A
# 1    H&A
# 2    H&A
# 3    H&A
# 4    H&A
# ..   ...
# 661  H&A
# 662  H&A
# 663  H&A
# 664  H&A
# 665  H&A
#
# [666 rows x 1 columns]

# %%
d3 = d2.join(ghmhd)
d3.to_csv('dimond_data.csv',index=None)

# %% [markdown]
# # 1 done

# %%
gcarat = []
gcarat1 = soup.find_all('td', class_='gia-carat')
for gia_carat in gcarat1:
    gcarat.append(gia_carat.text)

gcolor = []    
gcolor1 = soup.find_all('td', class_='gia-color')
for gia_color in gcolor1:
    gcolor.append(gia_color.text)

gclarity = []
gclarity1 = soup.find_all('td', class_='gia-clarity')
for gia_clarity in gclarity1:
    gclarity.append(gia_clarity.text)
    
gdmh = []
gdmh1 = soup.find_all('td', class_='gia-depth m-hide')
for gia_depth_m_hide in gdmh1:
    gdmh.append(gia_depth_m_hide.text)

gtmh = []
gtmh1 = soup.find_all('td', class_='gia-table m-hide')
for gia_table_m_hide in gtmh1:
    gtmh.append(gia_table_m_hide.text)

gcmh = []
gcmh1 = soup.find_all('td', 'gia-polish m-hide')
for gia_cut_m_hide in gcmh1:
    gcmh.append(gia_cut_m_hide.find('a').text)
    

gpmh = []
gpmh1 = soup.find_all('td', 'gia-polish m-hide')
for gia_polish_m_hide in gpmh1:
    gpmh.append(gia_polish_m_hide.find('a').text)

gsmh = []    
gsmh1 = soup.find_all('td', 'gia-polish m-hide')
for gia_sym_m_hide in gsmh1:
    gsmh.append(gia_sym_m_hide.find('a').text)

gfmh = []
gfmh1 = soup.find_all('td', class_='gia-flourescence m-hide')
for gia_flourescence_m_hide in gfmh1:
    gfmh.append(gia_flourescence_m_hide.text)

ghmh = []
ghmh1 = soup.find_all('td', class_='gia-heart m-hide')
for gia_heart_m_hide in ghmh1:
    ghmh.append(gia_heart_m_hide.text)

gstate = []
gstate1 = soup.find_all('td', class_='gia-state m-hide')
for gia_state_m_hid in gstate1:
    gstate.append(gia_state_m_hid.text)

# %%
print(gcarat)
# Out:
# ['0.40', '0.55', '0.85', '1.08', '1.16', '1.20', '1.82', '2.07', '2.51', '3.12', '3.52', '4.34', '5.27', '6.12', '9.18', '17.44', '24.88', '0.30', '0.30', '0.30']

# %%
print(gcolor)
# Out:
# ['D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D']

# %%
print(gclarity)
# Out:
# ['FL', 'FL', 'FL', 'FL', 'FL', 'FL', 'FL', 'FL', 'FL', 'FL', 'FL', 'FL', 'FL', 'FL', 'FL', 'FL', 'FL', 'IF', 'IF', 'IF']

# %%
print(gdmh)
# Out:
# ['61.6', '62.4', '62.3', '60.4', '62.7', '61.6', '62.5', '62.4', '61.8', '61.7', '61.9', '59.6', '61.5', '62.6', '61.1', '61.3', '61.6', '60.8', '62.1', '61.9']

# %%
print(gtmh)
# Out:
# ['58', '57', '57', '58', '57', '57', '56', '57', '58', '58', '57', '58', '58', '57', '57', '57', '57', '58', '55', '57']

# %%
print(gcmh)
# Out:
# ['EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX']

# %%
print(type(gpmh))
# Out:
# <class 'list'>

# %%
print(gsmh)
# Out:
# ['EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX', 'EX']

# %%
print(gfmh)
# Out:
# ['NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE']

# %%
print(ghmh)
# Out:
# ['\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n', '\nH&A\n\n\n\n']

# %%
print(str(gstate))
# Out:
# ['可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：6224158906\xa0\xa0\xa0\n\n\n含稅價格：NT53,147\n\n\n\n', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：2225073060\xa0\xa0\xa0\n\n\n含稅價格：NT108,677\n\n\n\n', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：5212837414\xa0\xa0\xa0\n\n\n含稅價格：NT267,836\n\n\n\n', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：6224197742\xa0\xa0\xa0\n\n\n含稅價格：NT694,088\n\n\n\n', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：6402769643\xa0\xa0\xa0\n\n\n含稅價格：NT745,502\n\n\n\n', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：6213989450\xa0\xa0\xa0\n\n\n含稅價格：NT771,209\n\n\n\n', '需預購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：6224211101\xa0\xa0\xa0\n\n\n含稅價格：NT1,577,079\n\n\n\n', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：2213134248\xa0\xa0\xa0\n\n\n含稅價格：NT2,660,672\n\n\n\n', '需預購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：2225245513\xa0\xa0\xa0\n\n\n含稅價格：NT3,299,548\n\n\n\n', '需預購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：2223543268\xa0\xa0\xa0\n\n\n含稅價格：NT5,878,206\n\n\n\n', '需預購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：2221031104\xa0\xa0\xa0\n\n\n含稅價格：NT6,955,325\n\n\n\n', '需預購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：6227374882\xa0\xa0\xa0\n\n\n含稅價格：NT9,678,177\n\n\n\n', '需預購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：2221341084\xa0\xa0\xa0\n\n\n含稅價格：NT15,360,377\n\n\n\n', '需預購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：1393725723\xa0\xa0\xa0\n\n\n含稅價格：NT18,078,908\n\n\n\n', '需預購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：2223156971\xa0\xa0\xa0\n\n\n含稅價格：NT31,457,301\n\n\n\n', '需預購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：2211866644\xa0\xa0\xa0\n\n\n含稅價格：NT75,189,090\n\n\n\n', '需預購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：2225414802\xa0\xa0\xa0\n\n\n含稅價格：NT104,243,616\n\n\n\n', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：3425253301\xa0\xa0\xa0\n\n\n含稅價格：NT27,881\n\n\n\n', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：2424990333\xa0\xa0\xa0\n\n\n含稅價格：NT27,881\n\n\n\n', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：6415986815\xa0\xa0\xa0\n\n\n含稅價格：NT27,881\n\n\n\n']

# %%
ghmh = map(lambda s: s.strip(), ghmh)

# %%
ghmh = map(lambda s: s.strip(), ghmh)
ghmh = list(ghmh)
print(ghmh)
# Out:
# ['H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A', 'H&A']

# %%
gstate4 = str(gstate).replace(u'\\t', '')
gstate4 = str(gstate4).replace(u'\\n', '')
gstate4 = str(gstate4).replace(u'\\xa0', ' ')
# print(type(gstate4))
gstate4 = gstate4.replace(u'    ', ' ')

# print(type(gstate4))
gstate4 = gstate4.replace(u'   ', ' ')
gstate4 = gstate4.replace(u'[', '')
gstate4 = gstate4.replace(u']', '')
gstate4 = gstate4.replace(u"'", '')
gstate4 = gstate4.replace(u",", '')
gstate4 = gstate4.replace(u"GIA證書連結：", '')
gstate4 = gstate4.replace(u"含稅價格：NT", '')
# print(gstate4)
# Out:
# <class 'str'>
# <class 'str'>
# 可訂購 6224158906 53147 可訂購 2225073060 108677 可訂購 5212837414 267836 可訂購 6224197742 694088 可訂購 6402769643 745502 可訂購 6213989450 771209 需預購 6224211101 1577079 可訂購 2213134248 2660672 需預購 2225245513 3299548 需預購 2223543268 5878206 需預購 2221031104 6955325 需預購 6227374882 9678177 需預購 2221341084 15360377 需預購 1393725723 18078908 需預購 2223156971 31457301 需預購 2211866644 75189090 需預購 2225414802 104243616 可訂購 3425253301 27881 可訂購 2424990333 27881 可訂購 6415986815 27881

# %%
gstate4 = gstate4.split()

# %%
gstate4
# Out:
# ['可訂購',
#  '6224158906',
#  '53147',
#  '可訂購',
#  '2225073060',
#  '108677',
#  '可訂購',
#  '5212837414',
#  '267836',
#  '可訂購',
#  '6224197742',
#  '694088',
#  '可訂購',
#  '6402769643',
#  '745502',
#  '可訂購',
#  '6213989450',
#  '771209',
#  '需預購',
#  '6224211101',
#  '1577079',
#  '可訂購',
#  '2213134248',
#  '2660672',
#  '需預購',
#  '2225245513',
#  '3299548',
#  '需預購',
#  '2223543268',
#  '5878206',
#  '需預購',
#  '2221031104',
#  '6955325',
#  '需預購',
#  '6227374882',
#  '9678177',
#  '需預購',
#  '2221341084',
#  '15360377',
#  '需預購',
#  '1393725723',
#  '18078908',
#  '需預購',
#  '2223156971',
#  '31457301',
#  '需預購',
#  '2211866644',
#  '75189090',
#  '需預購',
#  '2225414802',
#  '104243616',
#  '可訂購',
#  '3425253301',
#  '27881',
#  '可訂購',
#  '2424990333',
#  '27881',
#  '可訂購',
#  '6415986815',
#  '27881']

# %%
n = 3
c= [gstate4[i:i+n] for i in range(0, len(gstate4), n)]
c
# Out:
# [['可訂購', '6224158906', '53147'],
#  ['可訂購', '2225073060', '108677'],
#  ['可訂購', '5212837414', '267836'],
#  ['可訂購', '6224197742', '694088'],
#  ['可訂購', '6402769643', '745502'],
#  ['可訂購', '6213989450', '771209'],
#  ['需預購', '6224211101', '1577079'],
#  ['可訂購', '2213134248', '2660672'],
#  ['需預購', '2225245513', '3299548'],
#  ['需預購', '2223543268', '5878206'],
#  ['需預購', '2221031104', '6955325'],
#  ['需預購', '6227374882', '9678177'],
#  ['需預購', '2221341084', '15360377'],
#  ['需預購', '1393725723', '18078908'],
#  ['需預購', '2223156971', '31457301'],
#  ['需預購', '2211866644', '75189090'],
#  ['需預購', '2225414802', '104243616'],
#  ['可訂購', '3425253301', '27881'],
#  ['可訂購', '2424990333', '27881'],
#  ['可訂購', '6415986815', '27881']]

# %%
import pandas as pd

dff = pd.DataFrame(c)
dff.columns = ['State', 'GIA_NO', 'Price']
dff
# Out:
#    State      GIA_NO      Price
# 0    可訂購  6224158906      53147
# 1    可訂購  2225073060     108677
# 2    可訂購  5212837414     267836
# 3    可訂購  6224197742     694088
# 4    可訂購  6402769643     745502
# 5    可訂購  6213989450     771209
# 6    需預購  6224211101    1577079
# 7    可訂購  2213134248    2660672
# 8    需預購  2225245513    3299548
# 9    需預購  2223543268    5878206
# 10   需預購  2221031104    6955325
# 11   需預購  6227374882    9678177
# 12   需預購  2221341084   15360377
# 13   需預購  1393725723   18078908
# 14   需預購  2223156971   31457301
# 15   需預購  2211866644   75189090
# 16   需預購  2225414802  104243616
# 17   可訂購  3425253301      27881
# 18   可訂購  2424990333      27881
# 19   可訂購  6415986815      27881

# %%
d2 = pd.merge(dff, df, left_index = True, right_index=True)
d2
# Out:
#    State      GIA_NO      Price gcarat gcolor gclarity  gdmh gtmh gcmh gpmh  \
# 0    可訂購  6224158906      53147   0.40      D       FL  61.6   58   EX   EX
# 1    可訂購  2225073060     108677   0.55      D       FL  62.4   57   EX   EX
# 2    可訂購  5212837414     267836   0.85      D       FL  62.3   57   EX   EX
# 3    可訂購  6224197742     694088   1.08      D       FL  60.4   58   EX   EX
# 4    可訂購  6402769643     745502   1.16      D       FL  62.7   57   EX   EX
# 5    可訂購  6213989450     771209   1.20      D       FL  61.6   57   EX   EX
# 6    需預購  6224211101    1577079   1.82      D       FL  62.5   56   EX   EX
# 7    可訂購  2213134248    2660672   2.07      D       FL  62.4   57   EX   EX
# 8    需預購  2225245513    3299548   2.51      D       FL  61.8   58   EX   EX
# 9    需預購  2223543268    5878206   3.12      D       FL  61.7   58   EX   EX
# 10   需預購  2221031104    6955325   3.52      D       FL  61.9   57   EX   EX
# 11   需預購  6227374882    9678177   4.34      D       FL  59.6   58   EX   EX
# 12   需預購  2221341084   15360377   5.27      D       FL  61.5   58   EX   EX
# 13   需預購  1393725723   18078908   6.12      D       FL  62.6   57   EX   EX
# 14   需預購  2223156971   31457301   9.18      D       FL  61.1   57   EX   EX
# 15   需預購  2211866644   75189090  17.44      D       FL  61.3   57   EX   EX
# 16   需預購  2225414802  104243616  24.88      D       FL  61.6   57   EX   EX
# 17   可訂購  3425253301      27881   0.30      D       IF  60.8   58   EX   EX
# 18   可訂購  2424990333      27881   0.30      D       IF  62.1   55   EX   EX
# 19   可訂購  6415986815      27881   0.30      D       IF  61.9   57   EX   EX
#
#    gsmh  gfmh ghmh
# 0    EX  NONE  H&A
# 1    EX  NONE  H&A
# 2    EX  NONE  H&A
# 3    EX  NONE  H&A
# 4    EX  NONE  H&A
# 5    EX  NONE  H&A
# 6    EX  NONE  H&A
# 7    EX  NONE  H&A
# 8    EX  NONE  H&A
# 9    EX  NONE  H&A
# 10   EX  NONE  H&A
# 11   EX  NONE  H&A
# 12   EX  NONE  H&A
# 13   EX  NONE  H&A
# 14   EX  NONE  H&A
# 15   EX  NONE  H&A
# 16   EX  NONE  H&A
# 17   EX  NONE  H&A
# 18   EX  NONE  H&A
# 19   EX  NONE  H&A

# %%
d2.to_csv('dimond_test.csv',index=None)

# %%
import pandas as pd

d = {'gcarat':gcarat, 'gcolor':gcolor, 'gclarity':gclarity, 'gdmh':gdmh, 'gtmh':gtmh, 'gcmh':gcmh, 'gpmh':gpmh, 'gsmh':gsmh, 'gfmh':gfmh, 'ghmh':ghmh}
df = pd.DataFrame(d)
# df.to_csv('dimond_test.csv',index=None)

# %%
df
# Out:
#     gcarat        gcolor gclarity  gdmh gtmh gpmh gsmh         gfmh
# 0     0.40             D       FL  61.6   58   EX   EX         NONE
# 1     0.55             D       FL  62.4   57   EX   EX         NONE
# 2     0.85             D       FL  62.3   57   EX   EX         NONE
# 3     1.08             D       FL  60.4   58   EX   EX         NONE
# 4     1.16             D       FL  62.7   57   EX   EX         NONE
# ..     ...           ...      ...   ...  ...  ...  ...          ...
# 720   2.04  Fancy Yellow     VVS2  64.4   67   VG   VG  Medium Blue
# 721   1.14  Fancy Yellow      VS1  68.2   57   EX   EX         NONE
# 722   1.18  Fancy Yellow      VS1  68.4   55   EX   EX         NONE
# 723   1.27  Fancy Yellow      VS2  68.8   62   VG   VG  Medium Blue
# 724   0.51    Light Pink      VS2  62.2   56    G    G         NONE
#
# [725 rows x 8 columns]

# %%
info_items = soup.select('tbody.list td')
dinfo = []
for s in info_items:
    dinfo.append(s.text)
print(dinfo)
#     print(s.text)
# gno = info_items.select('td.gia-no')
# for item in info_items:
#     print(gno.text)
#     gcarat = item.find('td', 'gia-carat').text
#     gcolor = item.find('td', 'gia-color').text
#     gclarity = item.find('td', 'gia-clarity').text
#     gdmh = item.find('td', 'gia-depth m-hide').text
#     gtmh = item.find('td', 'gia-table m-hide').text
#     gcmh = item.find('td', 'gia-cut m-hide').a.text
#     gpmh = item.find('td', 'gia-polish m-hide').a.text
#     gsmh = item.find('td', 'gia-sym m-hide').a.text
#     gfmh = item.find('td', 'gia-flourescence m-hide').text
#     ghmh = item.find('td', 'gia-heart m-hide').a.text
#     gprice = item.find('td', 'gia-price').text
#     gstate = item.find('td', 'gia-state m-hide').text
#     ditem.append(gcarat)
#     print(ditem)
#     print('克拉{},顏色{},淨度{},深度{},桌面{},拋光{},對稱{},車工{},螢光{},八心八箭{},狀態{}'.format(gcarat,gcolor,gclarity,gdmh,gtmh,gcmh,gpmh,gsmh,gfmh,ghmh,gstate))
# print(info_items)
# Out:
# ['', '6224158906', '0.40', 'D', 'FL', '61.6', '58', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', 'NONE', '\nH&A\n\n\n\n', '50,422', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：6224158906\xa0\xa0\xa0\n\n\n含稅價格：NT52,943\n\n\n\n', '\n\n\n\n\n', '', '2225073060', '0.55', 'D', 'FL', '62.4', '57', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', 'NONE', '\nH&A\n\n\n\n', '103,105', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：2225073060\xa0\xa0\xa0\n\n\n含稅價格：NT108,260\n\n\n\n', '\n\n\n\n\n', '', '5212837414', '0.85', 'D', 'FL', '62.3', '57', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', 'NONE', '\nH&A\n\n\n\n', '254,102', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：5212837414\xa0\xa0\xa0\n\n\n含稅價格：NT266,807\n\n\n\n', '\n\n\n\n\n', '', '6224197742', '1.08', 'D', 'FL', '60.4', '58', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', 'NONE', '\nH&A\n\n\n\n', '658,499', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：6224197742\xa0\xa0\xa0\n\n\n含稅價格：NT691,424\n\n\n\n', '\n\n\n\n\n', '', '6402769643', '1.16', 'D', 'FL', '62.7', '57', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', 'NONE', '\nH&A\n\n\n\n', '707,277', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：6402769643\xa0\xa0\xa0\n\n\n含稅價格：NT742,641\n\n\n\n', '\n\n\n\n\n', '', '6213989450', '1.20', 'D', 'FL', '61.6', '57', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', 'NONE', '\nH&A\n\n\n\n', '731,665', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：6213989450\xa0\xa0\xa0\n\n\n含稅價格：NT768,248\n\n\n\n', '\n\n\n\n\n', '', '6224211101', '1.82', 'D', 'FL', '62.5', '56', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', 'NONE', '\nH&A\n\n\n\n', '1,496,215', '需預購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：6224211101\xa0\xa0\xa0\n\n\n含稅價格：NT1,571,026\n\n\n\n', '\n\n\n\n\n', '', '2213134248', '2.07', 'D', 'FL', '62.4', '57', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', 'NONE', '\nH&A\n\n\n\n', '2,524,246', '可訂購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：2213134248\xa0\xa0\xa0\n\n\n含稅價格：NT2,650,458\n\n\n\n', '\n\n\n\n\n', '', '2225245513', '2.51', 'D', 'FL', '61.8', '58', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', 'NONE', '\nH&A\n\n\n\n', '3,130,364', '需預購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：2225245513\xa0\xa0\xa0\n\n\n含稅價格：NT3,286,882\n\n\n\n', '\n\n\n\n\n', '', '2223543268', '3.12', 'D', 'FL', '61.7', '58', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', 'NONE', '\nH&A\n\n\n\n', '5,576,800', '需預購\t\t\t\t\t\t\t\t\t\t    \n\n\nGIA證書連結：2223543268\xa0\xa0\xa0\n\n\n含稅價格：NT5,855,640\n\n\n\n', '\n\n\n\n\n', '', '2221031104', '3.52', 'D', 'FL', '61.9', '57', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\n\n', '\nEX\n\n\nEX - EXCELLENT\nVG - VERY GOOD\nG - GOOD\n\ ...

# %% [markdown]
# # 1 END 2 START

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.aluxe.com/diamond-price/?page=1'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:57.0) Gecko/20100101 Firefox/57.0'}
response = requests.get(url=url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-Hant-TW">
# <head>
# <meta charset="utf-8"/>
# <!--手機解析度-->
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://www.aluxe.com/diamond-price/" hreflang="x-default" rel="alternate"/>
# <link href="https://www.aluxe.com/diamond-price/" hreflang="zh-Hant-TW" rel="alternate"/>
# <link href="https://www.aluxe.com/us/diamond-price/" hreflang="en" rel="alternate"/>
# <link href="https://www.aluxe.com/cn/diamond-price/" hreflang="zh-Hans-CN" rel="alternate"/>
# <link href="https://www.aluxe.com/hk/diamond-price/" hreflang="zh-Hant-HK" rel="alternate"/>
# <!--TDK-->
# <title>GIA認證鑽石價格，給您品質等級前2%的鑽石 | ALUXE 亞立詩鑽石</title>
# <meta content="亞立詩 GIA 認證鑽石價格情報 - 作為網路口碑第一推薦婚戒品牌，我們提供更優於國際品質的鑽石戒指及鑽石飾品，有親民的服務與價格，每顆鑽石 4C 等級只找符合 GIA 標準的前 2% 精選美鑽，更可以任意搭配鑽石克拉數、形狀、成色、淨度，找到最適合您的鑽石。" name="description"/>
# <meta content="鑽石,鑽戒,結婚戒指,戒指,gia" name="keywords"/>
# <!--Other Code-->
# <!--open graph protocol-->
# <meta content="GIA認證鑽石價格，給您品質等級前2%的鑽石 | ALUXE 亞立詩鑽石" property="og:title"/>
# <meta content="https://www.aluxe.com/upload/base_fb_img/twL_01ns_web_base_22G29_295kjubv3f.png" property="og:image"/>
# <meta content="亞立詩 GIA 認證鑽石價格情報 - 作為網路口碑第一推薦婚戒品牌，我們提供更優於國際品質的鑽石戒指及鑽石飾品，有親民的服務與價格，每顆鑽石 4C 等級只找符合 GIA 標準的前 2% 精選美鑽，更可以任意搭配鑽石克拉數、形狀、成色、淨度，找到最適合您的鑽石。" property="og:description"/>
# <meta content="https://www.aluxe.com/diamond-price/?page=1" property="og:url"/>
# <meta content="ALUXE 亞立詩鑽石 - GIA鑽石鑽戒、結婚戒指" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <!--bread script-->
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "BreadcrumbList",
#   "itemListElement": [
# 	  {
# 		"@type": "ListItem",
# 		"position": 1,
# 		"item": {
# 		  "@id": "https://www.aluxe.com/",
# 		  "name": "首頁"
# 			}
# 	  },
# 	  {
# 		"@type": "ListItem",
# 		"position": 2,
# 		"item": {
# 		  "@id": "https://www.aluxe.com/diamond-price/",
# 		  "name": "GIA鑽石價格"
# 			}
# 	  }  ]
# }
# </script>
# <meta content="telephone=no" name="format-detection"/>
# <!--css-->
# <link href="https://www.aluxe.com/css/master.css" rel="stylesheet" type="text/css"/>
# <link href="https://www.aluxe.com/css/catalog.css?v=0119" rel="stylesheet" type="text/css"/>
# <!--favor icon-->
# <link href="https://www.aluxe.com/images/touch-icon/favIcon.png" rel="shortcut icon">
# <!--touch_icon-->
# <link href="https://www.aluxe.com/images/touch-icon/apple-icon-60x60.png" rel="apple-touch-icon">
# <link href="https://www.aluxe.com/images/touch-icon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://www.aluxe.com/images/touch-icon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://www.aluxe.com/images/touch-icon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <script src="https://www.aluxe.com/public/js/jquery-1.12.4.min.js"></script>
# <script src="https://www.aluxe.com/public/js/jquery.blockUI.js"></script>
# <script src="https://www.aluxe.com/public/js/ajax_function.js"></script>
# <script src="https://www.aluxe.com/public/js/script.js?1753582511"></script>
# <script src="https://www.aluxe.com/public/lazyload.min.js"></script>
# <script>
#     function open_layer_detail(div_name,width,height){
#     	if(width==''){
#     		width=0;
#     	}
#     	if(height==''){
#     		height=0;
#     	}
#     	$.blockUI({
#     	message:$('#'+div_name),
#     		css:{
#     		cursor:'default',
#     		width: width + 'px',
#     		height:height+ 'px',
#     		padding:'0px',
#     		top:($(window).height()-height)/2 + 'px',
#     		left:($(window).width()-width)/2 + 'px'
#     		}
#     	});
#     }
#     function open_loading_status(loading_name){
#     	width=$('#'+loading_name).css('width').replace("px","");
#     	height=$('#'+loading_name).css('height').replace("px","");
#     	$.blockUI({
#     	message:$('#'+loading_name),
#     		css:{
#     		cursor:'default',
#     		border:'',
#     		backgroundColor:'',
#     		width: width + 'px',
#     		height:height+ 'px',
#     		padding:'0px',
#     		top:($(window).height()-height)/2 + 'px',
#     		left:($(window).width()-width)/2 + 'px'
#     		}
#     	});
#     }
#     function close_layer_detail(){
#     	$.unblockUI();
#     }
#     function close_top_layer_detail(){
#     	top.$.unblockUI();
#     }
#     //建立執行的div
#     $(function(){
#     	jQuery.browser = {};
#     	(function () {
#     	    jQuery.browser.msie = false;
#     	    jQuery.browser.version = 0;
#     	    if (navigator.userAgent.match(/MSIE ([0-9]+)\./)) {
#     	        jQuery.browser.msie = true;
#     	        jQuery.browser.version = RegExp.$1;
#     	    }
#     	})();
#     	$('body').prepend("<span id='iframe_string'></span>");
#     	$('body').prepend('<div id="waiting_action" style="display:none;text-align:center;position: absolute;z-index: 99998;color:#FFF;font-size:12px;border:0px;"><img src="https://www.aluxe.com/public/loading_type/loading_big.gif" hspace="2" align="absmiddle"/><br><img src="https://www.aluxe.com/public/loading_type/loading_text.png" hspace="2" align="absmiddle"/></div>');
#     });
#     //end
# </script>
# <script>
# 	var isMobile = false;
# 	var isTablet = false;
# </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PW6R3GL');</script>
# <!-- End Google Tag Manager -->
# <meta content="0lqi3xqjm3fmbx8r677o8z4urdz9ei" name="facebook-domain-verification">
# <meta content="1yKtFMKr6wifZOImeN-mKdR9G2-uMqItLM6Bue-mPwI" name="google-site-verification">
# <script>
# 	//宣告GTM事件
# 	var dataLayer = window.dataLayer || [];
# </script>
# </meta></meta></link></link></head>
# <body class="diamond-pricePage">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PW6R3GL" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!--會員登入浮動視窗-->
# <!--會員登入-->
# <!--loginArea-->
# <div class="loginArea moduleBox" id="moduleMember"><!--loginArea-->
# <div class="moduleInsBox">
# <a class="moduleClose moduleCloseStyle3 absolute" id="closeLogin"></a>
# <div class="login"><!--login-->
# <div class="titleBox3 center">
# <div class="title">會員登入</div>
# </div>
# <ul class="formList">
# <li class="full">
# <div class="item">
# <div class="left">E-mail</div>
# <div class="right">
# <input autocomplete="off" id="login_account" name="login_account" type="text"/>
# </div>
# </div>
# </li>
# <li class="full">
# <div class="item">
# <div class="left">密碼</div>
# <div class="right">
# <input autocomplete="off" id="login_pwd" name="login_pwd" type="password"/>
# </div>
# </div>
# </li>
# </ul>
# <div class="btn2">
# <a class="login_btn_status" onclick="login_btn();">會員登入</a>
# </div>
# <div class="textBox"><a class="fb" href="https://www.aluxe.com/third_party/Facebook/Login.php?refererurl=https%3A%2F%2Fwww.aluxe.com%2Fdiamond-price%2F%3Fpage%3D1">使用Facebook登入</a></div>
# <div class="textBox">
# <a href="https://www.aluxe.com/member/register/">立即註冊</a>
# <a class="btn_forget">忘記密碼?</a>
# </div>
# <div class="textBox">
# <div class="text">新系統上線，2021.02以前加入亞立詩的會員朋友，請使用「忘記密碼」設定新密碼喔!</div>
# </div>
# </div><!--login end-->
# <div class="forgetCheck"><!--forgetCheck-->
# <div class="titleBox3 center">
# <div class="title">忘記密碼</div>
# </div>
# <ul class="formList">
# <li class="full">
# <div class="item">
# <div class="left">E-mail</div>
# <div class="right">
# <input id="email_chk" name="email_chk" type="text"/>
# </div>
# </div>
# </li>
# </ul>
# <div class="btn2"><a class="forget_btn_status" onclick="forget_btn();" style="cursor:pointer">查詢</a></div>
# <a class="btn_relog">重新登入</a>
# </div><!--forgetCheck end-->
# </div>
# </div><!--loginArea end-->
# <script>
# function login_btn(){
# 	var errors='';
# 	if($('.loginArea #login_account').val()==''){
# 		errors += '- 必須填寫註冊的電子郵件。\n';
# 	}else if(! isEmail($('.loginArea #login_account').val())){
# 		errors += '- 必須填寫正確的電子郵件位址。\n';
# 	}
# 	if($('.loginArea #login_pwd').val()==''){
# 		errors += '- 必須填寫註冊的會員密碼。\n';
# 	}
# 	if(errors!=''){
# 		alert('錯誤訊息：\n'+errors);
# 		return false;
# 	}
#
# 	//token
# 	var CSRFToken = CSRFTokenJs.generate();
#
# 	$(".login_btn_status").addClass('loading');
# 	// $(".login_loading_status").show();
# 	jq_post_noloading(
# 		'https://www.aluxe.com/member/act/',
# 		{
# 			'act': 22,
# 			'login_account': $('.loginArea #login_account').val(),
# 			'login_pwd': $('.loginArea #login_pwd').val(),
# 			'CSRFTokenName': CSRFToken.name,
#             'CSRFTokenValue': CSRFToken.value
#         },
# 		'iframe_string'
# 	);
# }
# function forget_btn(){
# 	var errors='';
# 	if($('.loginArea #email_chk').val()=='' ){
# 		errors += '- 必須填寫註冊的電子郵件。\n';
# 	}else if(! isEmail($('.loginArea #email_chk').val())){
# 		errors += '- 必須填寫正確的電子郵件位址。\n';
# 	}
# 	if(errors!=''){
# 		alert('錯誤訊息：\n'+errors);
# 		return false;
# 	}
#
# 	//token
# 	var CSRFToken = CSRFTokenJs.generate();
#
# 	$(".forget_btn_status").hide();
# 	$(".forget_loading_status").show();
# 	jq_post_noloading(
# 		'https://www.aluxe.com/member/act/',
# 		{
# 			'act': 21,
# 			'email_chk': $('.loginArea #email_chk').val(),
# 			'CSRFTokenName': CSRFToken.name,
# 			'CSRFTokenValue': CSRFToken.value
# 		},
# 		'iframe_string'
# 	);
# }
# </script>
# <script>
# $(function(){
# 	/*開啟會員登入*/
# 	// $('body').on('click','.loginToggle',function(){
# 	// 	$.blockUI({
# 	// 		message:$('.loginArea'),
# 	// 		onOverlayClick: $.unblockUI,
# 	// 		onBlock:function(){
# 	// 			$('input').blur();
# 	// 		}
# 	// 	});
# 	// 	return false;
# 	// });
# 	/*關閉會員登入*/
# 	// $('#closeLogin').click(function(){
# 	// 	$.unblockUI();
# 	// 	return false;
# 	// });
# 	 $('.btn_forget').click(function(){
# 		$('.forgetCheck').slideDown(200);
# 		$('.login').slideUp(200);
# 	 });
# 	 $('.btn_relog').click(function(){
# 		$('.forgetCheck').slideUp(200);
# 		$('.login').slideDown(200);
# 	 })
# });
# </script>
# <div class="outerWrap"><!--outerWrap-->
# <a class="mobileStore" href="https://www.aluxe.com/reservation/">預約<br/>來店</a>
# <header class=""><!--header-->
# <div class="wrap full"><!--wrap-->
# <div class="leftBox"><!--leftBox-->
# <button class="btnMenu"><span></span></button>
# <div class="headCurrencyBox hasSubMenu"><!--headCurrencyBox-->
# <a class="btnCurrency" href="javascript:;">NT</a>
# <div class="subMenu">
# <a onclick="turnCurrency('NT')">NT</a>
# <a onclick="turnCurrency('twL_currency_21E13_b72in7wnb2')">USD</a>
# <a onclick="turnCurrency('twL_currency_21E13_he9kbdk3sy')">HKD</a>
# <a onclick="turnCurrency('twL_currency_21B08_2x329cqigw')">RMB</a>
# </div>
# </div><!--headCurrencyBox end-->
# <div class="headLanBox hasSubMenu"><!--headLanBox-->
# <a class="btnLan" href="javascript:;">
# <svg class="iconLanguage">
# <use xlink:href="#iconLanguage"></use>
# </svg>
# </a>
# <div class="subMenu">
# <a onclick="turnCurrency('','https://www.aluxe.com/', 'tw')">繁中</a>
# <a onclick="turnCurrency('twL_currency_21E13_he9kbdk3sy','https://www.aluxe.com/hk/', 'hk')">繁中(香港)</a>
# </div>
# </div><!--headLanBox end-->
# <div class="headSearchBox"><!--headSearchBox-->
# <a class="btnSearch" href="javascript:;">
# <svg class="iconSearch">
# <use xlink:href="#iconSearch"></use>
# </svg>
# </a>
# </div><!--headSearchBox end-->
# </div><!--leftBox end-->
# <nav class="menuBox"><!--menuBox-->
# <div class="logo">
# <a href="https://www.aluxe.com/" title="ALUXE 亞立詩鑽石 - GIA鑽石鑽戒、結婚戒指">
# <span class="text">ALUXE 亞立詩鑽石 - GIA鑽石鑽戒、結婚戒指</span>
# <svg class="webLogo">
# <use xlink:href="#webLogo2"></use>
# </svg>
# <!-- <svg class="webLogoText">
#                         <use xlink:href="#webLogoText"></use>
#                     </svg> -->
# </a>
# </div>
# <ul class="menu" itemscope="" itemtype="http://www.schema.org/SiteNavigationElement"><!--menu-->
# <li class="dropDown" itemprop="name">
# <a href="/engagement-ring-concept/" itemprop="url">
#                         求婚鑽戒                    </a>
# </li>
# <li class="dropDown" itemprop="name">
# <a href="/wedding-ring-concept/" itemprop="url">
#                         結婚戒指                    </a>
# </li>
# <li class="dropDown" itemprop="name">
# <a href="/fashion-jewelry-concept/" itemprop="url">
#                         時尚珠寶                    </a>
# </li>
# <li class="dropDown" itemprop="name">
# <a href="/disney" itemprop="url">
#                         迪士尼系列                    </a>
# </li>
# <li class="dropDown" itemprop="name"><a href="/about/" itemprop="url">關於ALUXE</a></li>
# <li class="dropDown" itemprop="name"><a href="/news/" itemprop="url">最新消息</a></li>
# <li itemprop="name"><a href="https://www.aluxe.com/diamond-price/" itemprop="url">GIA鑽石價格</a></li>
# </ul><!--menu end-->
# </nav><!--menuBox end-->
# <div class="rightBox"><!--rightBox-->
# <a class="btnStore" href="https://www.aluxe.com/reservation/">預約來店</a>
# <a class="btnShop" href="https://shop.aluxe.com/">
# <svg class="iconShop">
# <use xlink:href="#iconShop"></use>
# </svg>
#                 購物網站            </a>
# <div class="headMemberBox hasSubMenu">
# </div>
# <a class="favStyle" href="https://www.aluxe.com/favorite/">
# <svg class="iconFav">
# <use xlink:href="#iconFav"></use>
# </svg>
# <span class="count" id="headerFavor">0</span>
# </a>
# </div><!--rightBox end-->
# </div><!--wrap end-->
# <div class="headerSubMenuBox"><!--headerSubMenuBox-->
# <div class="wrap"><!--wrap-->
# <ul class="headerSubMenuList">
# <li>
# <div class="top"><!--top-->
# <div class="item"><!--item-->
# <div class="productImg">
# <a href="https://www.aluxe.com/engagement-ring/category/gorgeous/">
# <img alt="純粹華麗" class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_m_list_pic/twL_catalog_m_21E26_wdhxbm793k.jpg"/>
# </a>
# </div>
# <a class="title" href="https://www.aluxe.com/engagement-ring/category/gorgeous/" title="純粹華麗">
#                                             純粹華麗                                        </a>
# </div><!--item end-->
# <div class="item"><!--item-->
# <div class="productImg">
# <a href="https://www.aluxe.com/engagement-ring/category/solitaire/">
# <img alt="經典單鑽" class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_m_list_pic/twL_catalog_m_21E26_6uddzjzp9v.jpg"/>
# </a>
# </div>
# <a class="title" href="https://www.aluxe.com/engagement-ring/category/solitaire/" title="經典單鑽">
#                                             經典單鑽                                        </a>
# </div><!--item end-->
# <div class="item"><!--item-->
# <div class="productImg">
# <a href="https://www.aluxe.com/engagement-ring/category/wavy/">
# <img alt="靈動曲線" class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_m_list_pic/twL_catalog_m_21E26_s9d4hngyeg.jpg"/>
# </a>
# </div>
# <a class="title" href="https://www.aluxe.com/engagement-ring/category/wavy/" title="靈動曲線">
#                                             靈動曲線                                        </a>
# </div><!--item end-->
# <div class="item"><!--item-->
# <div class="productImg">
# <a href="https://www.aluxe.com/engagement-ring/category/pave/">
# <img alt="閃爍排鑽" class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_m_list_pic/twL_catalog_m_21E26_ety6erbjsi.jpg"/>
# </a>
# </div>
# <a class="title" href="https://www.aluxe.com/engagement-ring/category/pave/" title="閃爍排鑽">
#                                             閃爍排鑽                                        </a>
# </div><!--item end-->
# <div class="item"><!--item-->
# <div class="productImg">
# <a href="https://www.aluxe.com/engagement-ring/category/halo/">
# <img alt="璀燦擁抱" class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_m_list_pic/twL_catalog_m_21H30_cwbabeaq3u.png"/>
# </a>
# </div>
# <a class="title" href="https://www.aluxe.com/engagement-ring/category/halo/" title="璀燦擁抱">
#                                             璀燦擁抱                                        </a>
# </div><!--item end-->
# <div class="item"><!--item-->
# <div class="productImg">
# <a href="https://www.aluxe.com/engagement-ring/category/side-stone/">
# <img alt="側鑽星芒" class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_m_list_pic/twL_catalog_m_21E26_anyfxyhxpd.jpg"/>
# </a>
# </div>
# <a class="title" href="https://www.aluxe.com/engagement-ring/category/side-stone/" title="側鑽星芒">
#                                             側鑽星芒                                        </a>
# </div><!--item end-->
# </div><!--top end-->
# <div class="bottom"><!--bottom-->
# <div class="item">
# <a class="title" href="https://www.aluxe.com/engagement-ring/">ALL 求婚鑽戒</a>
# </div>
# <div class="item"><!--item-->
# <a class="title" href="https://www.aluxe.com/engagement-ring/category/alove/" title="A LOVE 系列">
#                                     A LOVE 系列                                    </a>
# </div><!--item end-->
# <div class="item"><!--item-->
# <a class="title" href="https://www.aluxe.com/engagement-ring/category/limited-offer/" title="初绽系列">
#                                     初绽系列                                    </a>
# </div><!--item end-->
# </div><!--bottom end-->
# </li>
# <li>
# <div class="top"><!--top-->
# <div class="item"><!--item-->
# <div class="productImg">
# <a href="https://www.aluxe.com/wedding-ring/category/couple/">
# <img alt="ALUXE 設計結婚對戒" class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_m_list_pic/twL_catalog_m_21E26_apqzsnixjx.jpg"/>
# </a>
# </div>
# <a class="title" href="https://www.aluxe.com/wedding-ring/category/couple/" title="ALUXE 設計結婚對戒">
#                                             ALUXE 設計結婚對戒                                        </a>
# </div><!--item end-->
# <div class="item"><!--item-->
# <div class="productImg">
# <a href="https://www.aluxe.com/wedding-ring/category/acredo/">
# <img alt="acredo 客製對戒" class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_m_list_pic/twL_catalog_m_21E26_dsgep7jgu6.jpg"/>
# </a>
# </div>
# <a class="title" href="https://www.aluxe.com
class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_m_list_pic/twL_catalog_m_21E26_zpsiympw5c.jpg"/>
# </a>
# </div>
# <a class="title" href="https://www.aluxe.com/disney-collection/category/disney-princess/" title="迪士尼公主系列">
#                                             迪士尼公主系列                                        </a>
# </div><!--item end-->
# </div><!--top end-->
# <div class="bottom"><!--bottom-->
# <div class="item">
# <a class="title" href="https://www.aluxe.com/disney-collection/">ALL 迪士尼系列</a>
# </div>
# </div><!--bottom end-->
# </li>
# <li>
# <div class="headerMenuStyle2"><!--headerMenuStyle2-->
# <div class="left"><!--left-->
# <div class="title">關於ALUXE</div>
# <div class="text">
# <a href="/about/brandstory/">品牌介紹</a> <a href="/about/service/">服務體驗</a> <a href="/about/after-sale-service/">售後服務</a> <a href="/shop-contact/">門市一覽</a> <a href="/knowledge/">知識中心</a> <a href="/acredo/">客製化戒指</a> </div>
# </div><!--left end-->
# <div class="right"><!--right-->
# <div class="itemListBox">
# <div class="list">
# <div class="pic"><a href="https://www.aluxe.com/about/"><img alt="" class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_menu_m_list_pic/twL_catalog_menu_m_20L03_cqsrfkdni8.png"/></a></div>
# <div class="text"><a href="https://www.aluxe.com/about/">品牌介紹</a></div>
# </div>
# <div class="list">
# <div class="pic"><a href="/about/service/"><img alt="" class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_menu_m_list_pic/twL_catalog_menu_m_20L03_3rjd4djbf4.jpg"/></a></div>
# <div class="text"><a href="/about/service/">服務體驗</a></div>
# </div>
# <div class="list">
# <div class="pic"><a href="/about/after-sale-service/"><img alt="" class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_menu_m_list_pic/twL_catalog_menu_m_20L03_emnvv75r3w.png"/></a></div>
# <div class="text"><a href="/about/after-sale-service/">售後服務</a></div>
# </div>
# </div>
# </div><!--right end-->
# </div><!--headerMenuStyle2 end-->
# </li>
# <li>
# <div class="headerMenuStyle2"><!--headerMenuStyle2-->
# <div class="left"><!--left-->
# <div class="title">最新消息</div>
# <div class="text">
# <a href="/news/category/news/">最新消息</a> <a href="/news/category/new-arrival/">新品上市</a> <a href="/news/category/limited-time-offer/">限時優惠</a> <a href="/news/category/store-announcement/">門市公告</a> <a href="/partner/">婚禮相關優惠</a> </div>
# </div><!--left end-->
# <div class="right"><!--right-->
# <div class="itemListBox">
# <div class="list">
# <div class="pic"><a href="/news/category/news/"><img alt="" class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_menu_m_list_pic/twL_catalog_menu_m_20L03_kxj9spxbbj.jpg"/></a></div>
# <div class="text"><a href="/news/category/news/">最新消息</a></div>
# </div>
# <div class="list">
# <div class="pic"><a href="/news/category/new-arrival/"><img alt="" class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_menu_m_list_pic/twL_catalog_menu_m_20L03_azswfm43c9.jpg"/></a></div>
# <div class="text"><a href="/news/category/new-arrival/">新品上市</a></div>
# </div>
# <div class="list">
# <div class="pic"><a href="/blog/"><img alt="" class="header-lazyload" data-src="https://www.aluxe.com/upload/catalog_menu_m_list_pic/twL_catalog_menu_m_21A27_w99jqcqar6.jpg"/></a></div>
# <div class="text"><a href="/blog/">幸福指南</a></div>
# </div>
# </div>
# </div><!--right end-->
# </div><!--headerMenuStyle2 end-->
# </li>
# </ul>
# </div><!--wrap end-->
# </div><!--headerSubMenuBox end-->
# <div class="searchBox">
# <div class="ins">
# <input class="searchInput" id="searchVal" placeholder="請輸入商品編號 / 文章" type="text"/>
# <div class="btn3"><a href="javascript:;" id="submitSearch">搜尋</a></div>
# </div>
# </div>
# <script>
#         let $searchVal = $('#searchVal');
#         let searchFn = {
#             value: function() {
#                 let val = $searchVal.val();
#                 if(val) {
#                     location.href = "https://www.aluxe.com/search/?keywords=" + val;
#                 } else {
#                     alert('請輸入關鍵字');
#                 }
#             },
#         };
#         $('#submitSearch').click(function() {
#             searchFn.value();
#         });
#         $searchVal.keydown(function(e) {
#             if(e.which == 13) {
#                 searchFn.value();
#             }
#         });
#
#         // let aa = new (function(){
#
#         //     this.value = function(){
#
#         //         a = 8;
#         //         return a;
#
#         //     };
#
#         //     let a = 5;
#
#         //     this.b = 6;
#
#         // })();
#     </script>
# </header><!--header end-->
# <div class="fixedSideBox"><!--fixedSideBox-->
# <a class="box" href="https://www.aluxe.com/reservation/">
# <span class="icon"><img alt="" src="https://www.aluxe.com/images/reservationRing.svg"/></span>
# <span class="text">預約試戴</span>
# </a>
# <a class="goTop goTopStyle">
# <i aria-hidden="true" class="fa fa-angle-up"></i>
# </a>
# </div><!--fixedSideBox end-->
# <div class="mobileMenuArea"><!--mobileMenuArea-->
# <div class="mobileMenuIns"><!--mobileMenuIns-->
# <ul class="mobileIconMenuList">
# <li>
# <a href="/engagement-ring-concept/">
# <svg class="iconMenu1">
# <use xlink:href="#iconMenu1"></use>
# </svg>
# <span class="text">求婚鑽戒</span>
# </a>
# </li>
# <li>
# <a href="/wedding-ring-concept/">
# <svg class="iconMenu2">
# <use xlink:href="#iconMenu2"></use>
# </svg>
# <span class="text">結婚戒指</span>
# </a>
# </li>
# <li>
# <a href="https://www.aluxe.com/diamond-price/">
# <svg class="iconMenu3">
# <use xlink:href="#iconMenu3"></use>
# </svg>
# <span class="text">GIA鑽石價格</span>
# </a>
# </li>
# <li>
# <a href="https://www.aluxe.com/news/">
# <svg class="iconMenu4">
# <use xlink:href="#iconMenu4"></use>
# </svg>
# <span class="text">最新消息</span>
# </a>
# </li>
# <li>
# <a href="https://www.aluxe.com/shop-contact/">
# <svg class="iconMenu5">
# <use xlink:href="#iconMenu5"></use>
# </svg>
# <span class="text">門市一覽</span>
# </a>
# </li>
# <li>
# <a href="https://www.aluxe.com/reservation/">
# <svg class="iconMenu6">
# <use xlink:href="#iconMenu6"></use>
# </svg>
# <span class="text">預約來店</span>
# </a>
# </li>
# </ul>
# <div class="mobileSectionTitle">Menu</div>
# <ul class="mobileMenu">
# <li>
# <a href="/engagement-ring-concept/">
#                         求婚鑽戒                    </a>
# <div class="subMenu">
# <a href="https://www.aluxe.com/engagement-ring/">All</a>
# <a href="https://www.aluxe.com/engagement-ring/category/gorgeous/">
#                             純粹華麗                        </a>
# <a href="https://www.aluxe.com/engagement-ring/category/solitaire/">
#                             經典單鑽                        </a>
# <a href="https://www.aluxe.com/engagement-ring/category/wavy/">
#                             靈動曲線                        </a>
# <a href="https://www.aluxe.com/engagement-ring/category/pave/">
# <a href="https://shop.aluxe.com/">購物網站</a>
# </li>
# </ul>
# <div class="mobileMenuItem">
# <div class="languageBox">
# <div class="titleStyle1">Language</div>
# <select class="selectStyle select_language">
# <option selected="" value="tw">繁體中文(台灣) (NT)</option>
# <option value="hk">繁體中文(香港) (HKD)</option>
# </select>
# <script type="text/javascript">
#
# $(function (){
# 	$('.select_language').on('change',function(){
# 		var selectId = $(this).val();
# 		console.log(selectId);
# 		if(selectId=='tw'){
# 			turnCurrency('NT','https://www.aluxe.com/');
# 		}else if(selectId=='hk'){
# 			turnCurrency('twL_currency_21E13_he9kbdk3sy','https://www.aluxe.com/hk');
# 		}else if(selectId=='cn'){
# 			turnCurrency('','https://www.aluxe.com/cn');
# 		}else if(selectId=='us'){
# 			turnCurrency('twL_currency_21E13_b72in7wnb2','https://www.aluxe.com/us');
# 		}
# 	});
# });
#
# </script> </div>
# </div>
# <div class="mobileMenuItem">
# <div class="btn3 large center"><a class="pink" href="https://www.aluxe.com/reservation/">預約來店</a></div>
# </div>
# </div><!--mobileMenuIns end-->
# </div><!--mobileMenuArea end-->
# <script>
#     $(function() {
#         let $mobileMenu = $('.mobileMenuArea');
#         let $header     = $('header');
#         $('.btnMenu').click(function() {
#             if(!$(this).hasClass('show')) {
#                 $(this).addClass('show');
#                 $header.addClass('otherOpen');
#                 $mobileMenu.addClass('show');
#                 $mobileMenu.css('top', $header.outerHeight());
#                 $('body').css('overflow', 'hidden');
#             } else {
#                 $(this).removeClass('show');
#                 $header.removeClass('otherOpen');
#                 $mobileMenu.removeClass('show');
#                 $('body').css('overflow', 'auto');
#             }
#         })
#         $('.mobileMenu li').each(function() {
#             let total = $(this).find('.subMenu a').length;
#             if(total > 0) {
#                 $(this).find(' > a').addClass('hasSubMenu');
#             }
#         });
#         $('.mobileMenu .hasSubMenu').click(function(e) {
#             e.preventDefault();
#             $(this).toggleClass('open');
#             $(this).next().slideToggle();
#         });
#
#         let $searchBox = $('.searchBox');
#         $('.btnSearch').click(function () {
#             if(!$searchBox.hasClass('show')) {
#                 $searchBox.addClass('show');
#                 $('.webMask').addClass('show');
#                 $('.searchInput').focus();
#                 $header.addClass('otherOpen');
#             } else {
#                 $searchBox.removeClass('show');
#                 $('.webMask').removeClass('show');
#                 $header.removeClass('otherOpen');
#             }
#         });
#         $(document).on('click', '.webMask', function() {
#             $searchBox.removeClass('show');
#             $('.webMask').removeClass('show');
#             $header.removeClass('otherOpen');
#         })
#     })
#
#
#
#     function jq_logout(url_link, qstr, Jump ) {
#         $.ajax({
#             url: url_link,
#             type: "post",
#             data: qstr,
#             cache: false,
#             dataType: "text",
#             success: function(mydata) {
#                 location.href=Jump;
#             },
#             error: function(error){
#                 console.log(error);
#             }
#         })
#     }
#
#     var alternateLanguageMap = [];
#                     alternateLanguageMap["tw"] = "zh-Hant-TW";
#                     alternateLanguageMap["us"] = "en";
#                     alternateLanguageMap["cn"] = "zh-Hans-CN";
#                     alternateLanguageMap["hk"] = "zh-Hant-HK";
#
#     function turnCurrency(cury,go_href='',tagetLangauge){
# 		//目前網址
#         var nowlocation = location.href;
#         if(go_href != ''){
#             nowlocation = go_href;
#         }
#
#         if(tagetLangauge != undefined && alternateLanguageMap[tagetLangauge] != undefined){
#             var url = $('link[rel="alternate"][hreflang="'+alternateLanguageMap[tagetLangauge]+'"]').prop('href');
#             if(url != undefined){
#                 nowlocation = url;
#             }
#         }
#
# 		$.ajax({
# 			url:'https://www.aluxe.com/langeChg/act/',
# 			type: "post",
# 			data: {
# 				"cury":cury,
# 				"nowlocation":nowlocation,
# 				"act":2
# 			},
# 			cache: false,
# 			dataType:"json",
# 			success: function(mydata) {
# 				if(mydata['code'] == "01" ){
# 					alert(mydata['msg']);
# 					location.reload();
# 				}else{
#
# 					if(mydata['code'] == "02"){
# 						location.href=nowlocation;
# 					}
# 				}
# 			},
# 			error: function(error){
# 				console.log(error);
# 			}
# 		})
# 	}
#
#     // function justCurrency(cury){
#     //     //目前網址
#     //     $.ajax({
#     //         url:'https://www.aluxe.com/langeChg/act/',
#     //         type: "post",
#     //         data: {
#     //             "cury":cury,
#     //             "act":2
#     //         },
#     //         cache: false,
#     //         dataType:"json",
#     //         success: function(mydata) {
#     //             if(mydata['code'] == "01" ){
#     //                 alert(mydata['msg']);
#     //                 location.reload();
#     //             }
#     //         },
#     //         error: function(error){
#     //             console.log(error);
#     //         }
#     //     })
#     // }
#     //外文版點擊pop切換語系視窗來到中文版，若幣別非台幣，會更改為台幣
# 	if(sessionStorage.getItem('popCurrency') == 'ok') {
# 		turnCurrency('NT');
# 		sessionStorage.setItem('popCurrency', '');
# 	}
#
# </script>
# <script>
# $(function() {
#     let menuaddClass = function(idx) {
#         $('.headerSubMenuBox').addClass('show');
#         $('.headerSubMenuList li').removeClass('show');
#         $('.headerSubMenuList li').eq(idx).addClass('show');
#         $('.menuMask').addClass('show');
#     };
#     let menuRemoveClass = function() {
#         $('.headerSubMenuBox, .headerSubMenuList li, .menuMask').removeClass('show');
#     };
#     let enterTarget = '';
#     let leaveTarget = '';
#     let idx = 0;
#     $('.menu .dropDown').on({
#         mouseenter: function(e) {
#
#             $("img.header-lazyload").lazyload();
#
#             enterTarget = e.target;
#             idx = $(this).index()
#             setTimeout(function() {
#                 menuaddClass(idx);
#             }, 20)
#         },
#         mouseleave: function(e) {
#             leaveTarget = e.target;
#             if(enterTarget == leaveTarget) {
#                 setTimeout(function() {
#                     if($('.headerSubMenuBox').is(':hover') == false) {
#                         menuRemoveClass();
#                     }
#                 }, 15)
#             }
#         }
#     });
#     $('.headerSubMenuBox').on({
#         mouseleave: function() {
#             menuRemoveClass();
#         }
#     });
#     $('header').after('<div class="menuMask"></div>')
# })
# </script> <!--banner-->
# <div class="bannerArea landingBanner diamondPriceBanner"><!--bannnerArea-->
# <div class="wrap"><!--wrap-->
# <div class="bannerBox"><!--bannerBox-->
# <ul id="banner">
# <li>
# <div class="Img"><img alt="GIA鑽石價格情報" src="https://www.aluxe.com/upload/banner_ins_list/twL_banner_ins_21D16_mzkwnm8s93.png"/></div>
# <div class="wrap justify-start align-center">
# <div>
# <div>
# <h1><span style='font-size:20px;font-size: 26px;letter-spacing: 0.08em;color: #FFFFFF;font-weight: 400;font-family: "Baskervville", "Noto Serif TC", serif;'>GIA鑽石價格情報</span></h1>
# <div class="en"><span style="color:#ffffff;">Diamond Price</span></div>
# <div class="note"><span style="color:#ffffff;">我們重視每顆鑽石的品質，從源頭把關，嚴格篩選，專注於提供符合 GIA 標準的前 2% 精選美鑽。</span></div>
# </div>
# </div> </div>
# </li>
# </ul>
# </div><!--bannerBox end-->
# </div><!--wrap end-->
# </div><!--bannerArea end-->
# <!--main-->
# <div class="mainArea"><!--mainArea-->
# <div class="wrap"><!--wrap-->
# <div class="titleBox noIcon"><!--titleBox-->
# <h2 class="title">鑽石篩選條件</h2>
# <div class="en">Filter</div>
# </div><!--titleBox end-->
# <div class="filterArea diamondPrice"><!--filterArea-->
# <div class="filterBox"><!--filterBox-->
# <ul class="filterList">
# <li class="filterListToggle">
# <div class="item"><!--item-->
# <h3 class="title">形狀</h3>
# <p class="text">鑽石的形狀，可以呈現不同的鑽戒風格，更能表現個人魅力</p>
# <div class="box"><!--box-->
# <a class="filterItem2 shape" data-class="shape" data-to="圓形" href="javascript:;">
# <span class="Img"><img alt="圓形" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></span>
# </a>
# <a class="filterItem2 shape" data-class="shape" data-to="公主方形" href="javascript:;">
# <span class="Img"><img alt="公主方形" src="https://www.aluxe.com/images/demo/diamondShape2.png"/></span>
# </a>
# <a class="filterItem2 shape" data-class="shape" data-to="心形" href="javascript:;">
# <span class="Img"><img alt="心形" src="https://www.aluxe.com/images/demo/diamondShape3.png"/></span>
# </a>
# <a class="filterItem2 shape" data-class="shape" data-to="枕形" href="javascript:;">
# <span class="Img"><img alt="枕形" src="https://www.aluxe.com/images/demo/diamondShape4.png"/></span>
# </a>
# <a class="filterItem2 shape" data-class="shape" data-to="祖母綠形" href="javascript:;">
# <span class="Img"><img alt="祖母綠形" src="https://www.aluxe.com/images/demo/diamondShape5.png"/></span>
# </a>
# <a class="filterItem2 shape" data-class="shape" data-to="雷地恩形" href="javascript:;">
# <span class="Img"><img alt="雷地恩形" src="https://www.aluxe.com/images/demo/diamondShape6.png"/></span>
# </a>
# <a class="filterItem2 shape" data-class="shape" data-to="橢圓形" href="javascript:;">
# <span class="Img"><img alt="橢圓形" src="https://www.aluxe.com/images/demo/diamondShape7.png"/></span>
# </a>
# <a class="filterItem2 shape" data-class="shape" data-to="梨形" href="javascript:;">
# <span class="Img"><img alt="梨形" src="https://www.aluxe.com/images/demo/diamondShape8.png"/></span>
# </a>
# <a class="filterItem2 shape" data-class="shape" data-to="馬眼型鑽石" href="javascript:;">
# <span class="Img"><img alt="馬眼型鑽石" src="https://www.aluxe.com/images/demo/diamondShape9.png"/></span>
# </a>
# </div><!--box end-->
# </div><!--item end-->
# </li>
# <li>
# <div class="item"><!--item-->
# <h3 class="title">成色</h3>
# <p class="text">鑽石的成色，D-F 透明無色，G-J 接近透明無色</p>
# <div class="box"><!--box-->
# <a class="filterItem2 circle" data-class="color" data-to="D" href="javascript:;">D</a>
# <a class="filterItem2 circle" data-class="color" data-to="E" href="javascript:;">E</a>
# <a class="filterItem2 circle" data-class="color" data-to="F" href="javascript:;">F</a>
# <a class="filterItem2 circle" data-class="color" data-to="G" href="javascript:;">G</a>
# <a class="filterItem2 circle" data-class="color" data-to="H" href="javascript:;">H</a>
# <a class="filterItem2 circle" data-class="color" data-to="I" href="javascript:;">I</a>
# <a class="filterItem2 circle" data-class="color" data-to="J" href="javascript:;">J</a>
# </div><!--box end-->
# </div><!--item end-->
# </li>
# <li>
# <div class="item"><!--item-->
# <h3 class="title">淨度</h3>
# <p class="text">鑽石的淨度，為衡量鑽石的純淨等級，由高至低為IF-S12</p>
# <div class="box"><!--box-->
# <a class="filterItem2 circle" data-class="clear" data-to="IF" href="javascript:;">IF</a>
# <a class="filterItem2 circle" data-class="clear" data-to="VVS1" href="javascript:;">VVS1</a>
# <a class="filterItem2 circle" data-class="clear" data-to="VVS2" href="javascript:;">VVS2</a>
# <a class="filterItem2 circle" data-class="clear" data-to="VS1" href="javascript:;">VS1</a>
# <a class="filterItem2 circle" data-class="clear" data-to="VS2" href="javascript:;">VS2</a>
# <a class="filterItem2 circle" data-class="clear" data-to="SI1" href="javascript:;">SI1</a>
# <a class="filterItem2 circle" data-class="clear" data-to="SI2" href="javascript:;">SI2</a>
# </div><!--box end-->
# </div><!--item end-->
# </li>
# <li>
# <div class="item"><!--item-->
# <h3 class="title">鑽石克拉</h3>
# <p class="text">鑽石的克拉數，代表鑽石的重量，200毫克等於1克拉，也可換算成100分</p>
# <div class="box"><!--box-->
# <div class="ins">
# <div class="priceRangeBox isPoint" data-end="5.00" data-max="5.00" data-min="0" data-start="0.00" id="priceRange"></div>
# <div class="priceRangeText ctArea">
# <input class="inputText minPrice" type="text"/>
# <span class="text">-</span>
# <input class="inputText maxPrice" type="text"/>
# </div>
# </div>
# </div><!--box end-->
# </div><!--item end-->
# </li>
# <li>
# <div class="item"><!--item-->
# <h3 class="title">價格範圍</h3>
# <p class="text">各種鑽石的價格，滿足大家不同的預算需求</p>
# <div class="box"><!--box-->
# <div class="ins">
# <div class="priceRangeBox" data-end="4086271" data-max="4086271" data-min="0" data-start="0.00" id="priceRange"></div>
# <div class="priceRangeText mArea">
# <input class="inputText minPrice" type="text"/>
# <span class="text">-</span>
# <input class="inputText maxPrice" type="text"/>
# </div>
# </div>
# </div><!--box end-->
# </div><!--item end-->
# </li>
# </ul>
# </div><!--filterBox end-->
# <div class="resultBox white"><!--resultBox-->
# <div class="left">
# <div class="btn2 light clearFilterBox">
# <a class="clearFilter" href="javascript:;" onclick="clearSearchGia('all')">清除所有篩選</a>
# </div>
# <div class="btn2 light toggleFilterBox">
# <a class="toggleFilter" data-less-text="較少選項" data-more-text="更多選項" href="javascript:;">更多選項</a>
# </div>
# </div>
# <div class="btn2 white right">
# <a class="clearFilter" href="javascript:;" id="chkFilter">確認篩選</a>
# </div>
# </div><!--resultBox end-->
# </div><!--filterArea end-->
# <div class="titleBox noIcon"><!--titleBox-->
# <h2 class="title">GIA鑽石</h2>
# <div class="note">共 1329 顆</div>
# </div><!--titleBox end-->
# <div class="giaArea diamondPrice">
# <div class="listBox"><!--listBox-->
# <div class="listTitle">
# <div class="box hide">形狀</div>
# <div class="box flex2">GIA證號</div>
# <div class="box flex1_2">克拉</div>
# <div class="box">成色</div>
# <div class="box">淨度</div>
# <div class="box hide">車工 / 拋光 / 對稱度</div>
# <!-- <div class="box">拋光</div>
#                         <div class="box">對稱度</div> -->
# <div class="box flex1_6">鑽石價格</div>
# <div class="box flex_5"></div>
# </div>
# <ul class="list" id="giaList">
# <li>
# <div class="item"><!--item-->
# <div class="box hide">
# <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window, document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '2342880895780638');
# fbq('track', 'PageView');
# </script>
# <noscript><imgheight="1" src="https://www.facebook.com/tr?id=1029163010773171&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"></imgheight="1"></noscript>
# <!--End Facebook Pixel Code -->
# <!--scrollreveal-->
# <script src="https://www.aluxe.com/public/js/scrollreveal.min.js"></script>
# <script>
# window.sr = ScrollReveal({mobile:true, scale:1, duration:800, easing:'linear'});
# $(function(){
#     if (sr.isSupported()) {
#         document.documentElement.classList.add('sr');
#         sr.reveal('.srBottom', {
#             distance: '20px',
#             viewFactor: 0.5
#         });
#
#         sr.reveal('.srLeft', {
#             distance: '20px',
#             origin: 'left',
#             viewFactor: 0.5
#         });
#
#         sr.reveal('.srRight', {
#             distance: '20px',
#             origin: 'right',
#             viewFactor: 0.5
#         });
#
#         sr.reveal('.srOpacity', {
#             distance: 0,
#             viewFactor: 0.5
#         });
#     }
# });
# </script>
# <script>
# $(function() {
#     $('.favStyle').click(function() {
#         $(this).toggleClass('isAdd');
#     })
# })
# </script>
# <script src="https://www.aluxe.com/lib/dragscroll.js"></script>
# <!--customer Js-->
# <link href="https://www.aluxe.com/lib/nouislider/nouislider.min.css" rel="stylesheet"/>
# <script src="https://www.aluxe.com/lib/nouislider/nouislider.min.js"></script>
# <script src="https://www.aluxe.com/lib/nouislider/wNumb.min.js"></script>
# <script>
# // var priceRange = document.getElementById('priceRange');
# var priceRange = document.querySelectorAll('.priceRangeBox');
# priceRange.forEach(function(data, index) {
#     var status = data.classList.contains('isPoint');
#     var input0 = document.querySelectorAll('.minPrice')[index];
#     var input1 = document.querySelectorAll('.maxPrice')[index];
#     var inputs = [input0, input1];
#
#
#     //價格
#     if( !status ){
#
#         noUiSlider.create(data, {
#             start: [
#                 parseInt(data.getAttribute('data-start')),
#                 parseInt(data.getAttribute('data-end'))
#             ],
#             connect: true,
#             step: 200,
#             range: {
#                 'min': parseInt(data.getAttribute('data-min')),
#                 // '25%': [parseInt(data.getAttribute('data-max')) * 0.2, 500],
#                 // '50%': [parseInt(data.getAttribute('data-max')) * 0.5, 500],
#                 // '75%': [parseInt(data.getAttribute('data-max')) * 0.8, 1000],
#                                         '50%': [70000 , 500],
#
#
#                 'max': parseInt(data.getAttribute('data-max'))
#             },
#                         format: wNumb({
#                 decimals: 0,
#             })
#
#                     });
#     }else{
#     //克拉
#         noUiSlider.create(data, {
#             start: [
#                 data.getAttribute('data-start'),
#                 data.getAttribute('data-end')
#             ],
#             step: 0.01,
#             connect: true,
#             range: {
#                 'min': parseInt(data.getAttribute('data-min')),
#                 '75%': [1.00, 1],
#                 'max': parseInt(data.getAttribute('data-max'))
#             },
#         });
#     }
#
#
#
#
#     data.noUiSlider.on('update', function (values, handle) {
#         inputs[handle].value = values[handle];
#     });
#     inputs.forEach(function (input, handle) {
#         input.addEventListener('change', function () {
#             priceRange.noUiSlider.setHandle(handle, this.value);
#         });
#         input.addEventListener('keydown', function (e) {
#             var values = priceRange.noUiSlider.get();
#             var value = Number(values[handle]);
#             // [[handle0_down, handle0_up], [handle1_down, handle1_up]]
#             var steps = priceRange.noUiSlider.steps();
#             // [down, up]
#             var step = steps[handle];
#             var position;
#             // 13 is enter,
#             // 38 is key up,
#             // 40 is key down.
#             switch (e.which) {
#                 case 13:
#                     priceRange.noUiSlider.setHandle(handle, this.value);
#                     break;
#                 case 38:
#                     // Get step to go increase slider value (up)
#                     position = step[1];
#                     // false = no step is set
#                     if (position === false) {
#                         position = 1;
#                     }
#                     // null = edge of slider
#                     if (position !== null) {
#                         priceRange.noUiSlider.setHandle(handle, value + position);
#                     }
#                     break;
#                 case 40:
#                     position = step[0];
#                     if (position === false) {
#                         position = 1;
#                     }
#                     if (position !== null) {
#                         priceRange.noUiSlider.setHandle(handle, value - position);
#                     }
#                     break;
#             }
#         });
#     });
# })
# </script>
# <script>
# $(function(){
#     $('.toggleFilter').click(function() {
#         let $this = $(this);
#         if(!$this.hasClass('open')) {
#             $this.addClass('open');
#             $this.text($this.data('less-text'));
#             $('.filterListToggle').slideDown();
#         } else {
#             $this.removeClass('open');
#             $this.text($this.data('more-text'));
#             $('.filterListToggle').slideUp();
#         }
#     });
#
#     var tempArray = new Array(); //宣告
#     $("#chkFilter").click(function(){
#         var i=0;
#         var ct_min = $('.ctArea .minPrice').val();
#         var ct_max = $('.ctArea .maxPrice').val();
#         var m_min = $('.mArea .minPrice').val();
#         var m_max = $('.mArea .maxPrice').val();
#         $('a[class^="filterItem2"]').each(function(index, element) {
#             if( $(this).hasClass("current") ){
#                 console.log(this);
#                 console.log( $(this).attr('data-class') );
#                 console.log( $(this).attr('data-to') );
#                 var tArray = new Array(); //宣告
#                 tArray.push( $(this).attr('data-class') );
#                 tArray.push( $(this).attr('data-to') );
#                 tempArray[i] = tArray;
#                 i++;
#             }
#         });
#         console.log(tempArray);
#         $.ajax({
#             url:'https://www.aluxe.com/diamond-price/act/',
#             type:"post",
#             data:{
#                 "act":3,
#                 "data":JSON.stringify(tempArray),
#                 "ct_min":ct_min,
#                 "ct_max":ct_max,
#                 "m_min":m_min,
#                 "m_max":m_max,
#             },
#             cache:false,
#             dataType:"text",
#             success:function(mydata){
#                 // location.reload();
#                 window.location.href = 'https://www.aluxe.com/diamond-price/';
#             }
#         });
#     });
#
#     $('.diamondPrductList').slick({
#         infinite: true,
#         slidesToShow: 5,
#         slidesToScroll: 1,
#         arrows: false,
#         autoplay: true,
#         autoplaySpeed: 3000,
#         cssEase: 'ease-in-out',
#         responsive: [
#             {
#                 breakpoint: 1281,
#                 settings: {
#                     slidesToShow: 4
#                 }
#             },
#             {
#                 breakpoint: 1025,
#                 settings: {
#                     slidesToShow: 3,
#                 }
#             },
#             {
#                 breakpoint: 641,
#                 settings: {
#                     slidesToShow: 2,
#                 }
#             }
#         ]
#     });
# });
# function clearSearchGia(delpr) {
#     if( delpr ){
#         $.ajax({
#             url:'https://www.aluxe.com/diamond-price/act/',
#             type:"post",
#             data:{
#                 "act":4,
#                 "data":delpr
#             },
#             cache:false,
#             dataType:"json",
#             success:function(mydata){
#                 if(mydata['code'] == '01'){
#                     alert( mydata['msg'] );
#                 }else{
#                     // location.reload();
#                     window.location.href = 'https://www.aluxe.com/diamond-price/';
#                 }
#             }
#         });
#     }
# }
# function clearSearchRange(cate) {
#     if( cate ){
#         $.ajax({
#             url:'https://www.aluxe.com/diamond-price/act/',
#             type:"post",
#             data:{
#                 "act":5,
#                 "data":cate
#             },
#             cache:false,
#             dataType:"json",
#             success:function(mydata){
#                 if(mydata['code'] == '01'){
#                     alert( mydata['msg'] );
#                 }else{
#                     // location.reload();
#                     window.location.href = 'https://www.aluxe.com/diamond-price/';
#                 }
#             }
#         });
#     }
# }
# function AddFavorGia(uid) {
#     if(uid){
#         $.ajax({
#             url:'https://www.aluxe.com/diamond-price/act/',
#             type: "post",
#             data: {
#                 "uid":uid,
#                 "act":6,
#             },
#             cache: false,
#             dataType:"json",
#             success: function(mydata) {
#                 if(mydata['code'] == "01" || mydata['code'] == "02"  ){
#                     alert(mydata['msg']);
#                 }else if( mydata['code'] == "03" ){
#                     $('.productIntroBox .btnFav').addClass("isAdd");
#                     $('#headerFavor').html( parseInt($('#headerFavor').html()) +1 );
#                     alert(mydata['msg']);
#                 }else if( mydata['code'] == "04" ){
#                     $('.productIntroBox .btnFav').removeClass("isAdd");
#                     $('#headerFavor').html( parseInt($('#headerFavor').html()) -1 );
#                     alert(mydata['msg']);
#                 }
#             },
#             error: function(error){
#                 console.log(error);
#             }
#         })
#     }
# }
# </script>
# </body>
# </html>

# %%
a1 = soup.find_all('ul', class_ = 'list')
a1
# a1.find_all('div', class_ = 'box flex2')
# Out:
# [<ul class="list" id="giaList">
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">6392508015</div>
#  <div class="box flex1_2">0.32 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS1</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 17,878                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0032DVS1_92508015')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0032DVS1_92508015</div>
#  <div class="text">GIA證號：6392508015</div>
#  <div class="text">市場報價：NT 32,979</div>
#  <div class="text">含稅價格：NT 18,772</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=6392508015" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">6405774094</div>
#  <div class="box flex1_2">0.32 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS1</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 17,878                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0032DVS1_05774094')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0032DVS1_05774094</div>
#  <div class="text">GIA證號：6405774094</div>
#  <div class="text">市場報價：NT 32,979</div>
#  <div class="text">含稅價格：NT 18,772</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=6405774094" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">6391799430</div>
#  <div class="box flex1_2">0.32 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS1</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 17,878                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0032DVS1_91799430')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0032DVS1_91799430</div>
#  <div class="text">GIA證號：6391799430</div>
#  <div class="text">市場報價：NT 32,979</div>
#  <div class="text">含稅價格：NT 18,772</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=6391799430" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">7401638949</div>
#  <div class="box flex1_2">0.32 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS1</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 17,878                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0032DVS1_01638949')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0032DVS1_01638949</div>
#  <div class="text">GIA證號：7401638949</div>
#  <div class="text">市場報價：NT 32,979</div>
#  <div class="text">含稅價格：NT 18,772</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=7401638949" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">5396424287</div>
#  <div class="box flex1_2">0.32 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS1</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 17,878                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0032DVS1_96424287')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0032DVS1_96424287</div>
#  <div class="text">GIA證號：5396424287</div>
#  <div class="text">市場報價：NT 32,979</div>
#  <div class="text">含稅價格：NT 18,772</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=5396424287" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">1409768042</div>
#  <div class="box flex1_2">0.32 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS1</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 17,878                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0032DVS1_09768042')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0032DVS1_09768042</div>
#  <div class="text">GIA證號：1409768042</div>
#  <div class="text">市場報價：NT 32,979</div>
#  <div class="text">含稅價格：NT 18,772</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=1409768042" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">6402436552</div>
#  <div class="box flex1_2">0.32 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS1</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 17,878                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0032DVS1_02436552')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0032DVS1_02436552</div>
#  <div class="text">GIA證號：6402436552</div>
#  <div class="text">市場報價：NT 32,979</div>
#  <div class="text">含稅價格：NT 18,772</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=6402436552" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">3415279746</div>
#  <div class="box flex1_2">0.32 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS1</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 17,878                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0032DVS1_15279746')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0032DVS1_15279746</div>
#  <div class="text">GIA證號：3415279746</div>
#  <div class="text">市場報價：NT 32,979</div>
#  <div class="text">含稅價格：NT 18,772</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=3415279746" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">6442872116</div>
#  <div class="box flex1_2">0.32 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS1</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 17,878                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0032DVS1_42872116')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0032DVS1_42872116</div>
#  <div class="text">GIA證號：6442872116</div>
#  <div class="text">市場報價：NT 32,979</div>
#  <div class="text">含稅價格：NT 18,772</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=6442872116" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">7421480864</div>
#  <div class="box flex1_2">0.32 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS1</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 17,878                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0032DVS1_21480864')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0032DVS1_21480864</div>
#  <div class="text">GIA證號：7421480864</div>
#  <div class="text">市場報價：NT 32,979</div>
#  <div class="text">含稅價格：NT 18,772</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=7421480864" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">6412730058</div>
#  <div class="box flex1_2">0.32 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS1</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 17,878                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0032DVS1_12730058')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0032DVS1_12730058</div>
#  <div class="text">GIA證號：6412730058</div>
#  <div class="text">市場報價：NT 32,979</div>
#  <div class="text">含稅價格：NT 18,772</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=6412730058" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">6392968974</div>
#  <div class="box flex1_2">0.32 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS1</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 17,878                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0032DVS1_92968974')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0032DVS1_92968974</div>
#  <div class="text">GIA證號：6392968974</div>
#  <div class="text">市場報價：NT 32,979</div>
#  <div class="text">含稅價格：NT 18,772</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=6392968974" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">2427156523</div>
#  <div class="box flex1_2">0.32 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS1</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 17,878                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0032DVS1_27156523')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0032DVS1_27156523</div>
#  <div class="text">GIA證號：2427156523</div>
#  <div class="text">市場報價：NT 32,979</div>
#  <div class="text">含稅價格：NT 18,772</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=2427156523" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2
div>
#  <div class="text">市場報價：NT 30,084</div>
#  <div class="text">含稅價格：NT 17,247</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=7408854461" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">6402659177</div>
#  <div class="box flex1_2">0.33 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS2</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 16,425                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0033DVS2_02659177')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0033DVS2_02659177</div>
#  <div class="text">GIA證號：6402659177</div>
#  <div class="text">市場報價：NT 30,084</div>
#  <div class="text">含稅價格：NT 17,247</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=6402659177" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">6402170478</div>
#  <div class="box flex1_2">0.33 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS2</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 16,425                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0033DVS2_02170478')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0033DVS2_02170478</div>
#  <div class="text">GIA證號：6402170478</div>
#  <div class="text">市場報價：NT 30,084</div>
#  <div class="text">含稅價格：NT 17,247</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=6402170478" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  <li>
#  <div class="item"><!--item-->
#  <div class="box hide">
#  <div class="shape"><img alt="" src="https://www.aluxe.com/images/demo/diamondShape1.png"/></div>
#  </div>
#  <div class="box flex2">5403699512</div>
#  <div class="box flex1_2">0.33 ct</div>
#  <div class="box">D</div>
#  <div class="box">VS2</div>
#  <div class="box hide">
#                                              EX /                                            EX /                                            EX                                        </div>
#  <div class="box flex1_6">
#                                              NT 16,425                                        </div>
#  <div class="box flex_5 favStyle check" onclick="AddFavorGia('X0033DVS2_03699512')">
#  <svg class="iconFav">
#  <use xlink:href="#iconFav"></use>
#  </svg>
#  </div>
#  </div><!--item end-->
#  <div class="bottom"><!--bottom-->
#  <div class="text">商品編號：X0033DVS2_03699512</div>
#  <div class="text">GIA證號：5403699512</div>
#  <div class="text">市場報價：NT 30,084</div>
#  <div class="text">含稅價格：NT 17,247</div>
#  <div class="text">證書：<a href="https://www.gia.edu/report-check?reportno=5403699512" target="_blank">GIA連結</a></div>
#  <div class="text mobile">車工：EX</div>
#  <div class="text mobile">拋光：EX</div>
#  <div class="text mobile">對稱度：EX</div>
#  </div><!--bottom end-->
#  </li>
#  </ul>]

# %%
giaall = []
giaall1 = soup.find_all('div', class_ = 'box')
for i in giaall1:
    giaall.append(i.text)

# %%
giaall
# Out:
# ['\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n',
#  '\nD\nE\nF\nG\nH\nI\nJ\n',
#  '\nIF\nVVS1\nVVS2\nVS1\nVS2\nSI1\nSI2\n',
#  '\n\n\n\n\n-\n\n\n\n',
#  '\n\n\n\n\n-\n\n\n\n',
#  '形狀',
#  'GIA證號',
#  '克拉',
#  '成色',
#  '淨度',
#  '車工 / 拋光 / 對稱度',
#  '鑽石價格',
#  '',
#  '\n\n',
#  '6392508015',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '6405774094',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '6391799430',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '7401638949',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '5396424287',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '1409768042',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '6402436552',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '3415279746',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '6442872116',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '7421480864',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '6412730058',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '6392968974',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '2427156523',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '2407693589',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '1403067339',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '6405786250',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '1399625219',
#  '0.32 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 17,878                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '2417827244',
#  '0.34 ct',
#  'D',
#  'VS1',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 18,996                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '2407975314',
#  '0.31 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 15,430                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '1405915291',
#  '0.31 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 15,430                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '1418001467',
#  '0.32 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 15,928                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '3405748699',
#  '0.32 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 15,928                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '6402152231',
#  '0.32 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 15,928                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '6402852838',
#  '0.32 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 15,928                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '5406337751',
#  '0.32 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 15,928                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '2417065541',
#  '0.32 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 15,928                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '5406047419',
#  '0.32 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 15,928                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '7408959136',
#  '0.32 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 15,928                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '6402284667',
#  '0.32 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 15,928                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '7408561466',
#  '0.33 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 16,425                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '1403416666',
#  '0.33 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 16,425                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '1403683418',
#  '0.33 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 16,425                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '6402749206',
#  '0.33 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 16,425                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '1417161433',
#  '0.33 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 16,425                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '6415117686',
#  '0.33 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 16,425                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '3395885066',
#  '0.33 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 16,425                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '7408854461',
#  '0.33 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 16,425                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '6402659177',
#  '0.33 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 16,425                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '6402170478',
#  '0.33 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 16,425                                        ',
#  '\n\n\n\n',
#  '\n\n',
#  '5403699512',
#  '0.33 ct',
#  'D',
#  'VS2',
#  '\n                                            EX /                                            EX /                                            EX                                        ',
#  '\n                                            NT 16,425                                        ',
#  '\n\n\n\n']

# %%
import re

a2 = str(giaall).replace(u'\\n', '')
# a2 = a2.replace(u'DEFGHIJ', '')
# a2 = a2.replace(u'IFVVS1VVS2VS1VS2SI1SI2', '')
a2 = a2.replace(u"['', 'DEFGHIJ', 'IFVVS1VVS2VS1VS2SI1SI2', '-', '-', '形狀', 'GIA證號', '克拉', '成色', '淨度', '車工 / 拋光 / 對稱度', '鑽石價格', '', '', ", '')
a2 = a2.replace(u"'                                            EX /                                            EX /                                            EX                                        ',", '')
a2 = a2.replace(u" ", '')
a2 = a2.replace(u"ct", '')
a2 = a2.replace(u"'", '')
a2 = a2.replace(u",", ' ')
a2 = a2.replace(u"]", '')
# a2 = a2.replace(u'GIA證號', '')
# a2 = a2.replace(u'克拉', '')
# a2 = a2.replace(u'成色', '')
# a2 = a2.replace(u'淨度', '')
# a2 = a2.replace(u'車工 / 拋光 / 對稱度', '')
# a2 = a2.replace(u'鑽石價格', '')
# a2 = a2.replace(u'\\n\\n', '')
# a2 = a2.replace(u'\\n                                            EX /                                            EX /                                            EX                               ', '')
# a2 = a2.replace(u'\\n                                            NT 17,878                                        ', '')
# a2 = a2.replace(u'         ', '')
a2_1 = re.sub(r"NT\d\d \d\d\d", "", a2)
a2_1.split()
# a2.split()
# Out:
# ['6392508015',
#  '0.32',
#  'D',
#  'VS1',
#  '6405774094',
#  '0.32',
#  'D',
#  'VS1',
#  '6391799430',
#  '0.32',
#  'D',
#  'VS1',
#  '7401638949',
#  '0.32',
#  'D',
#  'VS1',
#  '5396424287',
#  '0.32',
#  'D',
#  'VS1',
#  '1409768042',
#  '0.32',
#  'D',
#  'VS1',
#  '6402436552',
#  '0.32',
#  'D',
#  'VS1',
#  '3415279746',
#  '0.32',
#  'D',
#  'VS1',
#  '6442872116',
#  '0.32',
#  'D',
#  'VS1',
#  '7421480864',
#  '0.32',
#  'D',
#  'VS1',
#  '6412730058',
#  '0.32',
#  'D',
#  'VS1',
#  '6392968974',
#  '0.32',
#  'D',
#  'VS1',
#  '2427156523',
#  '0.32',
#  'D',
#  'VS1',
#  '2407693589',
#  '0.32',
#  'D',
#  'VS1',
#  '1403067339',
#  '0.32',
#  'D',
#  'VS1',
#  '6405786250',
#  '0.32',
#  'D',
#  'VS1',
#  '1399625219',
#  '0.32',
#  'D',
#  'VS1',
#  '2417827244',
#  '0.34',
#  'D',
#  'VS1',
#  '2407975314',
#  '0.31',
#  'D',
#  'VS2',
#  '1405915291',
#  '0.31',
#  'D',
#  'VS2',
#  '1418001467',
#  '0.32',
#  'D',
#  'VS2',
#  '3405748699',
#  '0.32',
#  'D',
#  'VS2',
#  '6402152231',
#  '0.32',
#  'D',
#  'VS2',
#  '6402852838',
#  '0.32',
#  'D',
#  'VS2',
#  '5406337751',
#  '0.32',
#  'D',
#  'VS2',
#  '2417065541',
#  '0.32',
#  'D',
#  'VS2',
#  '5406047419',
#  '0.32',
#  'D',
#  'VS2',
#  '7408959136',
#  '0.32',
#  'D',
#  'VS2',
#  '6402284667',
#  '0.32',
#  'D',
#  'VS2',
#  '7408561466',
#  '0.33',
#  'D',
#  'VS2',
#  '1403416666',
#  '0.33',
#  'D',
#  'VS2',
#  '1403683418',
#  '0.33',
#  'D',
#  'VS2',
#  '6402749206',
#  '0.33',
#  'D',
#  'VS2',
#  '1417161433',
#  '0.33',
#  'D',
#  'VS2',
#  '6415117686',
#  '0.33',
#  'D',
#  'VS2',
#  '3395885066',
#  '0.33',
#  'D',
#  'VS2',
#  '7408854461',
#  '0.33',
#  'D',
#  'VS2',
#  '6402659177',
#  '0.33',
#  'D',
#  'VS2',
#  '6402170478',
#  '0.33',
#  'D',
#  'VS2',
#  '5403699512',
#  '0.33',
#  'D',
#  'VS2']

# %%
giaall2 = []
giaall1_2 = soup.find_all('div', class_ = 'text')
for i in giaall1_2:
    giaall2.append(i.text)

# %%
giaall2
# Out:
# ['新系統上線，2021.02以前加入亞立詩的會員朋友，請使用「忘記密碼」設定新密碼喔!',
#  '\n品牌介紹 服務體驗 售後服務 門市一覽 知識中心 客製化戒指 ',
#  '品牌介紹',
#  '服務體驗',
#  '售後服務',
#  '\n最新消息 新品上市 限時優惠 門市公告 婚禮相關優惠 ',
#  '最新消息',
#  '新品上市',
#  '幸福指南',
#  '商品編號：X0032DVS1_92508015',
#  'GIA證號：6392508015',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_05774094',
#  'GIA證號：6405774094',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_91799430',
#  'GIA證號：6391799430',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_01638949',
#  'GIA證號：7401638949',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_96424287',
#  'GIA證號：5396424287',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_09768042',
#  'GIA證號：1409768042',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_02436552',
#  'GIA證號：6402436552',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_15279746',
#  'GIA證號：3415279746',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_42872116',
#  'GIA證號：6442872116',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_21480864',
#  'GIA證號：7421480864',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_12730058',
#  'GIA證號：6412730058',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_92968974',
#  'GIA證號：6392968974',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_27156523',
#  'GIA證號：2427156523',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_07693589',
#  'GIA證號：2407693589',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_03067339',
#  'GIA證號：1403067339',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_05786250',
#  'GIA證號：6405786250',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS1_99625219',
#  'GIA證號：1399625219',
#  '市場報價：NT 32,979',
#  '含稅價格：NT 18,772',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0034DVS1_17827244',
#  'GIA證號：2417827244',
#  '市場報價：NT 35,022',
#  '含稅價格：NT 19,946',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0031DVS2_07975314',
#  'GIA證號：2407975314',
#  '市場報價：NT 28,255',
#  '含稅價格：NT 16,201',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0031DVS2_05915291',
#  'GIA證號：1405915291',
#  '市場報價：NT 28,255',
#  '含稅價格：NT 16,201',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS2_18001467',
#  'GIA證號：1418001467',
#  '市場報價：NT 29,169',
#  '含稅價格：NT 16,724',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS2_05748699',
#  'GIA證號：3405748699',
#  '市場報價：NT 29,169',
#  '含稅價格：NT 16,724',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS2_02152231',
#  'GIA證號：6402152231',
#  '市場報價：NT 29,169',
#  '含稅價格：NT 16,724',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS2_02852838',
#  'GIA證號：6402852838',
#  '市場報價：NT 29,169',
#  '含稅價格：NT 16,724',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS2_06337751',
#  'GIA證號：5406337751',
#  '市場報價：NT 29,169',
#  '含稅價格：NT 16,724',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS2_17065541',
#  'GIA證號：2417065541',
#  '市場報價：NT 29,169',
#  '含稅價格：NT 16,724',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS2_06047419',
#  'GIA證號：5406047419',
#  '市場報價：NT 29,169',
#  '含稅價格：NT 16,724',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS2_08959136',
#  'GIA證號：7408959136',
#  '市場報價：NT 29,169',
#  '含稅價格：NT 16,724',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0032DVS2_02284667',
#  'GIA證號：6402284667',
#  '市場報價：NT 29,169',
#  '含稅價格：NT 16,724',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0033DVS2_08561466',
#  'GIA證號：7408561466',
#  '市場報價：NT 30,084',
#  '含稅價格：NT 17,247',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0033DVS2_03416666',
#  'GIA證號：1403416666',
#  '市場報價：NT 30,084',
#  '含稅價格：NT 17,247',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0033DVS2_03683418',
#  'GIA證號：1403683418',
#  '市場報價：NT 30,084',
#  '含稅價格：NT 17,247',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0033DVS2_02749206',
#  'GIA證號：6402749206',
#  '市場報價：NT 30,084',
#  '含稅價格：NT 17,247',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0033DVS2_17161433',
#  'GIA證號：1417161433',
#  '市場報價：NT 30,084',
#  '含稅價格：NT 17,247',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0033DVS2_15117686',
#  'GIA證號：6415117686',
#  '市場報價：NT 30,084',
#  '含稅價格：NT 17,247',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0033DVS2_95885066',
#  'GIA證號：3395885066',
#  '市場報價：NT 30,084',
#  '含稅價格：NT 17,247',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0033DVS2_08854461',
#  'GIA證號：7408854461',
#  '市場報價：NT 30,084',
#  '含稅價格：NT 17,247',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0033DVS2_02659177',
#  'GIA證號：6402659177',
#  '市場報價：NT 30,084',
#  '含稅價格：NT 17,247',
#  '證書：GIA連結',
#  '車工：EX',
#  '拋光：EX',
#  '對稱度：EX',
#  '商品編號：X0033DVS2
'證書：GIA連結', '車工：EX', '拋光：EX', '對稱度：EX', '商品編號：X0033DVS2_03416666', 'GIA證號：1403416666', '市場報價：NT 30,084', '含稅價格：NT 17,247', '證書：GIA連結', '車工：EX', '拋光：EX', '對稱度：EX', '商品編號：X0033DVS2_03683418', 'GIA證號：1403683418', '市場報價：NT 30,084', '含稅價格：NT 17,247', '證書：GIA連結', '車工：EX', '拋光：EX', '對稱度：EX', '商品編號：X0033DVS2_02749206', 'GIA證號：6402749206', '市場報價：NT 30,084 ...

# %%
giaprice1 = re.findall(r"\d+[,]\d+", a3)

# %%
, '含稅價格：\d+', '車工：[A-Z]', '拋光：[A-Z]', '對稱度：[A-Z]'
# Out:
# ("'含稅價格：\\d+',", "'車工：[A-Z]',", "'拋光：[A-Z]',", "'對稱度：[A-Z]'")

# %%
len(giaprice1)
# Out:
# 80

# %%
giaprice2 = []
for i in range(0, len(giaprice1)):
    if i%2 == 0:
        giaprice2.append(giaprice1[i])
giaprice2
# Out:
# ['32,979',
#  '32,979',
#  '32,979',
#  '32,979',
#  '32,979',
#  '32,979',
#  '32,979',
#  '32,979',
#  '32,979',
#  '32,979',
#  '32,979',
#  '32,979',
#  '32,979',
#  '32,979',
#  '32,979',
#  '32,979',
#  '32,979',
#  '35,022',
#  '28,255',
#  '28,255',
#  '29,169',
#  '29,169',
#  '29,169',
#  '29,169',
#  '29,169',
#  '29,169',
#  '29,169',
#  '29,169',
#  '29,169',
#  '30,084',
#  '30,084',
#  '30,084',
#  '30,084',
#  '30,084',
#  '30,084',
#  '30,084',
#  '30,084',
#  '30,084',
#  '30,084',
#  '30,084']

# %%
giaprice_str = str(giaprice2).replace(u"[", '')
giaprice_str = str(giaprice_str).replace(u"]", '')
giaprice_str = str(giaprice_str).replace(u"'", '')
giaprice_str = str(giaprice_str).replace(u",", '')

giaprice_str
# Out:
# '32979 32979 32979 32979 32979 32979 32979 32979 32979 32979 32979 32979 32979 32979 32979 32979 32979 35022 28255 28255 29169 29169 29169 29169 29169 29169 29169 29169 29169 30084 30084 30084 30084 30084 30084 30084 30084 30084 30084 30084'

# %%
giaprice2 = giaprice_str.split()

giaprice2
# Out:
# ['32979',
#  '32979',
#  '32979',
#  '32979',
#  '32979',
#  '32979',
#  '32979',
#  '32979',
#  '32979',
#  '32979',
#  '32979',
#  '32979',
#  '32979',
#  '32979',
#  '32979',
#  '32979',
#  '32979',
#  '35022',
#  '28255',
#  '28255',
#  '29169',
#  '29169',
#  '29169',
#  '29169',
#  '29169',
#  '29169',
#  '29169',
#  '29169',
#  '29169',
#  '30084',
#  '30084',
#  '30084',
#  '30084',
#  '30084',
#  '30084',
#  '30084',
#  '30084',
#  '30084',
#  '30084',
#  '30084']

# %%
gia_p = re.findall(r"拋光：[A-Z]+", a3)
gia_p
# Out:
# ['拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX',
#  '拋光：EX']

# %%
gia_p_str = str(gia_p).replace(u"[", '')
gia_p_str = str(gia_p_str).replace(u"]", '')
gia_p_str = str(gia_p_str).replace(u"拋光：", '')
gia_p_str = str(gia_p_str).replace(u"'", '')
gia_p_str = str(gia_p_str).replace(u",", '')
gia_p_str
# Out:
# 'EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX'

# %%
gia_p = gia_p_str.split()
gia_p
# Out:
# ['EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX']

# %%
gia_s = re.findall(r"對稱度：[A-Z]+", a3)
gia_s
# Out:
# ['對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX',
#  '對稱度：EX']

# %%
gia_s_str = str(gia_s).replace(u"[", '')
gia_s_str = str(gia_s_str).replace(u"]", '')
gia_s_str = str(gia_s_str).replace(u"對稱度：", '')
gia_s_str = str(gia_s_str).replace(u"'", '')
gia_s_str = str(gia_s_str).replace(u",", '')
gia_s_str
# Out:
# 'EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX EX'

# %%
gia_s = gia_s_str.split()
gia_s
# Out:
# ['EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX',
#  'EX']

# %% [markdown]
# # 2 START

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.aluxe.com/diamond-price/?page=1'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:57.0) Gecko/20100101 Firefox/57.0'}
response = requests.get(url=url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
a1 = soup.find_all('ul', class_ = 'list')
